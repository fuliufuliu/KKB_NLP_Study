# %% [markdown]
# ## Lesson-01

# %%
simple_grammar = """
sentence => noun_phrase verb_phrase
noun_phrase => Article Adj* noun
Adj* => null | Adj Adj*
verb_phrase => verb noun_phrase
Article =>  一个 | 这个
noun =>   女人 |  篮球 | 桌子 | 小猫
verb => 看着   |  坐在 |  听着 | 看见
Adj =>  蓝色的 | 好看的 | 小小的
"""

# %%
another_grammar = """
# 
"""

# %%
import random

# %%
def adj():  return random.choice('蓝色的 | 好看的 | 小小的'.split('|')).split()[0]

# %%
def adj_star():
    return random.choice([lambda : '', lambda : adj() + adj_star()])()

# %%
adj_star()
# Out:
# ''

# %% [markdown]
# ## But the question is ?

# %% [markdown]
# 如果我们更换了语法，会发现所有写过的程序，都要重新写。:(

# %%
adj_grammar = """
Adj* => null | Adj Adj*
Adj =>  蓝色的 | 好看的 | 小小的
"""

# %%
def create_grammar(grammar_str, split='=>', line_split='\n'):
    grammar = {}
    for line in grammar_str.split(line_split):
        if not line.strip(): continue
        exp, stmt = line.split(split)
        grammar[exp.strip()] = [s.split() for s in stmt.split('|')]
    return grammar

# %%
grammar = create_grammar(adj_grammar)

# %%
grammar['Adj*']
# Out:
# [['null'], ['Adj', 'Adj*']]

# %%
choice = random.choice

def generate(gram, target):
    if target not in gram: return target # means target is a terminal expression
    
    expaned = [generate(gram, t) for t in choice(gram[target])]
    return ''.join([e if e != '/n' else '\n' for e in expaned if e != 'null'])

# %%
example_grammar = create_grammar(simple_grammar)

# %%
example_grammar
# Out:
# {'sentence': [['noun_phrase', 'verb_phrase']],
#  'noun_phrase': [['Article', 'Adj*', 'noun']],
#  'Adj*': [['null'], ['Adj', 'Adj*']],
#  'verb_phrase': [['verb', 'noun_phrase']],
#  'Article': [['一个'], ['这个']],
#  'noun': [['女人'], ['篮球'], ['桌子'], ['小猫']],
#  'verb': [['看着'], ['坐在'], ['听着'], ['看见']],
#  'Adj': [['蓝色的'], ['好看的'], ['小小的']]}

# %%
generate(gram=example_grammar, target='sentence')
# Out:
# '一个小小的蓝色的蓝色的好看的篮球看见这个好看的小猫'

# %%
#在西部世界里，一个”人类“的语言可以定义为：

human = """
human = 自己 寻找 活动
自己 = 我 | 俺 | 我们 
寻找 = 找找 | 想找点 
活动 = 乐子 | 玩的
"""


#一个“接待员”的语言可以定义为

host = """
host = 寒暄 报数 询问 业务相关 结尾 
报数 = 我是 数字 号 ,
数字 = 单个数字 | 数字 单个数字 
单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9 
寒暄 = 称谓 打招呼 | 打招呼
称谓 = 人称 ,
人称 = 先生 | 女士 | 小朋友
打招呼 = 你好 | 您好 
询问 = 请问你要 | 您需要
业务相关 = 玩玩 具体业务
玩玩 = null
具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
结尾 = 吗？
"""

# %%
for i in range(20):
    print(generate(gram=create_grammar(host, split='='), target='host'))
# Out:
# 先生,您好我是3号,您需要打牌吗？
# 你好我是5号,您需要打牌吗？
# 您好我是3号,请问你要赌博吗？
# 您好我是5号,请问你要打牌吗？
# 先生,您好我是5号,请问你要打牌吗？
# 您好我是9号,您需要打牌吗？
# 您好我是3号,请问你要赌博吗？
# 小朋友,您好我是6号,您需要赌博吗？
# 女士,您好我是87号,您需要喝酒吗？
# 您好我是2272号,请问你要打牌吗？
# 女士,您好我是8号,您需要打猎吗？
# 你好我是24号,请问你要赌博吗？
# 先生,您好我是7号,您需要打猎吗？
# 小朋友,您好我是2号,请问你要打猎吗？
# 你好我是824号,您需要喝酒吗？
# 您好我是4号,您需要打猎吗？
# 小朋友,你好我是17号,您需要打猎吗？
# 你好我是834号,您需要打猎吗？
# 您好我是1号,您需要喝酒吗？
# 你好我是41号,请问你要赌博吗？

# %% [markdown]
# 希望能够生成最合理的一句话？

# %% [markdown]
# ## Data Driven

# %% [markdown]
# 我们的目标是，希望能做一个程序，然后，当输入的数据变化的时候，我们的程序不用重写。Generalization.

# %% [markdown]
# AI? 如何能自动化解决问题，我们找到一个方法之后，输入变了，我们的这个方法，不用变。

# %%
simpel_programming = '''
programming => if_stmt | assign | while_loop
while_loop => while ( cond ) { change_line stmt change_line }
if_stmt => if ( cond )  { change_line stmt change_line } | if ( cond )  { change_line stmt change_line } else { change_line stmt change_line } 
change_line => /N
cond => var op var
op => | == | < | >= | <= 
stmt => assign | if_stmt
assign => var = var
var =>  var _ num | words 
words => words _ word | word 
word => name | info |  student | lib | database 
nums => nums num | num
num => 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9 | 0
'''

# %%
print(generate(gram=create_grammar(simpel_programming, split='=>'), target='programming'))
# Out:
# if(student_database==lib_1){/Nstudent_1=info_2_5_2_4/N}else{/Nif(lib_0_5_1_5_1_6<=info){/Nname_lib=name_7/N}else{/Nif(lib_info_6_4_9>=student_name){/Nif(lib<=info_student){/Nif(student_student_name_lib==info){/Ndatabase_name=lib_info_8_1/N}else{/Nlib_info_name_4_3=name/N}/N}else{/Nstudent_8_2=info_8/N}/N}else{/Nif(student_name_name_lib_infodatabase){/Ndatabase_database_info_0_7_4_2=database_name_lib/N}else{/Nstudent_3_1=lib_name_name_1_3/N}/N}/N}/N}

# %%
def pretty_print(line):
    # utility tool function
    lines = line.split('/N')
    
    code_lines = []
    
    for i, sen in enumerate(lines):
        if i < len(lines) / 2: 
            #print()
            code_lines.append(i * "  " + sen)
        else:
            code_lines.append((len(lines) - i) * " " + sen)
    
    return code_lines

# %%
generated_programming = []

for i in range(20):
    generated_programming += pretty_print(generate(gram=create_grammar(simpel_programming, split='=>'), target='programming'))

# %%
for line in generated_programming:
    print(line)
# Out:
# if(database_0<=database){
#   if(database<=lib_lib){
#     student_database=lib_lib
#       }else{
#         student_name_student_database_6=database_name_6_9
#           }
#             }else{
#               if(student<=lib_lib){
#                 database_lib_name=database_lib
#                   }else{
#          if(info_student>=lib_info_lib_5_3_9_8){
#         if(name_infoinfo_database_name_0){
#        name_student_info_lib_student_5_0_9_1=lib
#       }else{
#      lib_database_7_6=lib_database
#     }
#    }
#   }
#  }
# database_info_student=database_database
# if(student_8_4_1<=info){
#   student_lib_info_lib=name_2_2_4_7_6_6_3_1_4
#     }else{
#       if(name_info_8_5==lib_2_0_5){
#         if(info_nameinfo_9_2_8){
#           if(info<student_info_lib_name_lib){
#      student=name_4_9
#     }
#    }
#   }
#  }
# if(student_database_student_namelib){
#   if(name_lib_database_student_4_9>=database_lib){
#     if(lib<lib_name_8){
#       database=name
#         }else{
#           student_3_8_3_2=name_3_8
#             }
#               }
#                 }else{
#                   if(info_name_name_lib>=database_5){
#          info_info_lib_student_database=database_student_info
#         }else{
#        if(name_name_database<=database){
#       lib_info_7=info_info
#      }else{
#     name_database_info_6_6_9_5_6=database
#    }
#   }
#  }
# if(lib_7_0_6_4_0_7<=name_0_1){
#   name=info_database
#  }
# if(info_lib_2==student_student_3){
#   lib_name_1_0=lib_3_1_4_1
#  }
# if(student_lib_4_5_3_4_5_7database_database){
#   if(info_database_student_6<=lib_5){
#     student_lib=lib
#       }else{
#         student_name_5_1_8_0=info
#           }
#             }else{
#       if(database_lib==student){
#      database_name_6=student_lib_lib_lib_8
#     }else{
#    student_name_6_9_9=info
#   }
#  }
# while(database_database_infolib_database_database_7_7){
#   lib=info
#  }
# lib_info_5_3=info_lib_name_lib_5
# while(info_student_database_student>=database){
#   info_8=database
#  }
# name_name_lib_lib_student_info_2=student_name
# if(info<=info){
#   if(name_info_name_student_lib_4>=student_lib_lib_3_0){
#     if(database_0_7==database_lib_student){
#       if(name_database<info_lib_database_database){
#         database_info_info_student_6_5=lib
#           }else{
#             if(info<=database){
#               database_9=database_lib_0_9_0
#        }
#       }
#      }else{
#     lib_name_info=student_database_lib_database_0_1_0
#    }
#   }
#  }
# name=lib_info_info_6_9
# student_9=name
# if(name_4_5_2_0_8<=lib){
#   database=student_info
#  }
# lib=name
# student_name_8_9=student_3_9_8
# info_lib_5_5_3=lib_lib_student
# if(info_8>=info_lib_database){
#   lib_name_8_3=student_lib_database_info_lib
#  }
# while(lib_9_6info_lib_7){
#   if(database_9_2_1_0>=lib){
#     if(student_student_lib_5==student_info){
#       database_9=lib
#    }
#   }
#  }

# %% [markdown]
# # Language Model

# %% [markdown]
# $$ language\_model(String) = Probability(String) \in (0, 1) $$

# %% [markdown]
# $$ Pro(w_1 w_2 w_3 w_4) = Pr(w_1 | w_2 w_3 w_ 4) * Pr(w2 | w_3 w_4) * Pr(w_3 | w_4) * Pr(w_4)$$

# %% [markdown]
# $$ Pro(w_1 w_2 w_3 w_4) \sim Pr(w_1 | w_2 ) * P(w2 | w_3 ) * Pr(w_3 | w_4) * Pr(w_4)$$

# %% [markdown]
#  $$ Pro(w_1 w_2 w_3 w_4) \sim Pr(w_1 | w_2 ) * P(w2 | w_3 ) * Pr(w_3 | w_4) * Pr(w_4)$$

# %% [markdown]
# how to get $ Pr(w1 | w2 w3 w4) $ ?

# %%
import random

# %%
random.choice(range(100))
# Out:
# 33

# %%
filename = 'D:/downloads/sqlResult_1558435.csv'

# %%
import pandas as pd

# %%
content = pd.read_csv(filename, encoding= 'gb18030') # 'gb18030'

# %%
content.head()
# Out:
#       id      author                  source  \
# 0  89617         NaN  快科技@http://www.kkj.cn/
# 1  89616         NaN  快科技@http://www.kkj.cn/
# 2  89615         NaN  快科技@http://www.kkj.cn/
# 3  89614         NaN                     新华社
# 4  89613  胡淑丽_MN7479                   深圳大件事
#
#                                              content  \
# 0  此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1  骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2  此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3    这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
#
#                                              feature  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...
#
#                            title  \
# 0           小米MIUI 9首批机型曝光：共计15款
# 1     骁龙835在Windows 10上的性能表现有望改善
# 2      一加手机5细节曝光：3300mAh、充半小时用1天
# 3  葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4       44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
#
#                                                  url
# 0     http://www.cnbeta.com/articles/tech/623597.htm
# 1     http://www.cnbeta.com/articles/tech/623599.htm
# 2     http://www.cnbeta.com/articles/tech/623601.htm
# 3  http://world.huanqiu.com/hot/2017-06/10866126....
# 4  http://news.163.com/17/0618/00/CN617P3Q0001875...

# %%
articles = content['content'].tolist()

# %%
len(articles)
# Out:
# 89611

# %%
import re

# %%
def token(string):
    # we will learn the regular expression next course.
    return re.findall('\w+', string)

# %%
import jieba

# %%
from collections import Counter

# %%
with_jieba_cut = Counter(jieba.cut(articles[110]))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\FULIU~1.DES\AppData\Local\Temp\jieba.cache
# Loading model cost 0.794 seconds.
# Prefix dict has been built successfully.

# %%
with_jieba_cut.most_common()[:10]
# Out:
# [('，', 88),
#  ('的', 73),
#  ('。', 39),
#  ('\r\n', 27),
#  ('了', 20),
#  ('们', 18),
#  ('工作队', 16),
#  ('村民', 15),
#  ('收割', 14),
#  ('、', 12)]

# %%
''.join(token(articles[110]))
# Out:
# '在外国名著麦田里的守望者中作者想要守护麦田里如自己内心一般纯真的孩子们而驻村干部们也在这个炎热的夏天里撸袖子上阵真正做起了村民们的麦田守望者三夏时节不等人你看到了吗不停翻涌起伏仿若铺陈至天边的金黄麦浪中那若隐若现的人影是自治区新闻出版广电局驻和田市肖尔巴格乡合尼村工作队的队员与工作队组织的青年志愿者在这个炎热的夏季他们深入田间地头帮助村民们收割小麦扛起收麦机麦田中的每个人都显得兴致勃勃一天下来就近22亩小麦收割完毕志愿者麦麦提亚森擦去满脸的汗水高兴地告诉驻村队员我们青年志愿者应该多做贡献为村里的脱贫致富出把力工作队带着我们为村里的老人服务看到那些像我爷爷奶奶一样的老人赞许感谢的目光我体会到了帮助他人的快乐自治区新闻出版广电局驻村工作队孙敏艾力依布拉音麦收时节我们在一起6月中旬的和田墨玉麦田金黄静待收割6月14日15日两天自治区高级人民法院驻和田地区墨玉县吐外特乡罕勒克艾日克村工作队与48名村民志愿者一道帮助村里29户有需要的村民进行小麦收割工作田间地头罕勒克艾日克村志愿队的红旗迎风飘扬格外醒目10余台割麦机一起轰鸣男人们在用机器收割小麦的同时几名妇女也加入到志愿队构成了一道美丽的麦收风景休息空闲工作队员和村民们坐在树荫下田埂上互相问好聊天语言交流有困难就用手势动作比划着聊天有趣地交流方式不时引来阵阵欢笑大家在一同享受丰收和喜悦也一同增进着彼此的情感和友谊自治区高级人民法院驻村工作队周春梅艾地艾木阿不拉细看稻菽千重浪6月15日自治区煤田灭火工程局的干部职工们再一次跋涉1000多公里来到了叶城县萨依巴格乡阿亚格欧尔达贝格村见到了自己的亲戚现场处处都透出掩盖不住的喜悦一声声亲切的谢谢一个个结实的拥抱都透露出浓浓的亲情没坐一会儿在嘘寒问暖中大家了解到在麦收的关键时刻部分村民家中却存在收割难的问题小麦成熟期短收获的时间集中天气的变化对小麦最终产量的影响极大如果不能及时收割会有不小损失的于是大家几乎立刻就决定要帮助亲戚们收割麦子在茂密的麦地里干部们每人手持一把镰刀一字排开挽起衣袖卷起裤腿挥舞着镰刀进行着无声的竞赛骄阳似火汗如雨下但这都挡不住大家的热情随着此起彼伏的镰刀割倒麦子的刷刷声响不一会一束束沉甸甸的麦穗就被整齐地堆放了起来当看到自己亲手收割的金黄色麦穗被一簇簇地打成捆运送到晒场每个人的脸上都露出了灿烂的笑容自治区煤田灭火工程局驻村工作队马浩南这是一个收获多多的季节6月13日清晨6时许和田地区民丰县若雅乡特开墩村的麦田里已经传来马达轰鸣声原来是自治区质监局驻村工作队趁着天气尚且凉爽开始了麦田的收割工作忙碌间隙志愿者队伍搬来清凉的水村民们拎来鲜甜的西瓜抹一把汗水吃一牙西瓜甜蜜的汁水似乎流进了每一个人的心里说起割麦子对于生活在这片土地上的村民来说是再平常不过的事但是对于工作队队员们来说却是陌生的自治区质监局驻民丰县若克雅乡博斯坦村工作队队员们一开始觉得十几个人一起收割二亩地应该会挺快的结果却一点不简单镰刀拿到自己手里割起来考验才真正的开始大家弓着腰弯着腿亦步亦趋手上挥舞着镰刀时刻注意不要让镰刀割到自己脚下还要留心不要把套种的玉米苗踩伤不一会儿就已经汗流浃背了抬头看看身边的村民早就远远地割到前面去了只有今年已经56岁的工作队队长李树刚有割麦经验多少给队员们挽回了些面子赶不上村民们割麦子的速度更不要说搞定收割机这台大家伙了现代化的机械收割能成倍提升小麦的收割速度李树刚说不过能有这样的体验拉近和村民的距离也是很难得的体验自治区质监局驻村工作队王辉马君刚我们是麦田的守护者为了应对麦收新疆银监局驻和田县塔瓦库勒乡也先巴扎村工作队一早就从经济支援和人力支援两方面做好了准备一方面工作队帮村里购入了5台小麦收割机另一边还组织村干部青年团员等组成了6支近百人的收割先锋突击队帮助村民们抢收麦子看着及时归仓的麦子村民们喜得合不拢嘴纷纷摘下自家杏树上的杏子送给工作队金黄的麦穗温暖了村民们的心香甜的杏子温暖了工作队员的心麦子加杏子拉近了村民和队员们的心新疆银监局驻村工作队王继发免责声明本文仅代表作者个人观点与环球网无关其原创性以及文中陈述文字和内容未经本站证实对本文以及其中全部或者部分内容文字的真实性完整性及时性本站不作任何保证或承诺请读者仅作参考并请自行核实相关内容'

# %%
articles_clean = [''.join(token(str(a)))for a in articles]

# %%
len(articles_clean)
# Out:
# 89611

# %%
with open('article_9k.txt', 'w') as f:
    for a in articles_clean:
        f.write(a + '\n')

# %%
# !ls  #windows 下不能运行 ，换成！dir
# !dir
# Out:
#  驱动器 C 中的卷没有标签。
#  卷的序列号是 CC50-9CB0
#
#  C:\Users\fuliu.DESKTOP-NDRSTOG 的目录
#
# 2020/01/06  00:56    <DIR>          .
# 2020/01/06  00:56    <DIR>          ..
# 2018/09/07  00:06    <DIR>          .anaconda
# 2018/08/25  14:20    <DIR>          .android
# 2018/08/26  19:55    <DIR>          .astropy
# 2018/10/04  18:28             2,186 .bash_history
# 2020/01/05  12:45    <DIR>          .conda
# 2020/01/05  13:01               192 .condarc
# 2019/12/15  20:55    <DIR>          .config
# 2019/04/22  14:40    <DIR>          .dotnet
# 2019/04/09  22:32               455 .gitconfig
# 2019/01/12  19:49    <DIR>          .GoLand2018.3
# 2019/02/17  23:10    <DIR>          .gsutil
# 2019/05/26  11:15    <DIR>          .HLVirtualBox
# 2018/10/05  02:18    <DIR>          .IntelliJIdea2018.2
# 2020/01/05  23:41    <DIR>          .ipynb_checkpoints
# 2018/09/20  19:17    <DIR>          .ipython
# 2018/09/20  21:27    <DIR>          .jupyter
# 2018/09/23  02:06    <DIR>          .keras
# 2019/12/15  20:53    <DIR>          .matplotlib
# 2019/04/25  17:26    <DIR>          .nuget
# 2019/04/24  16:40    <DIR>          .omnisharp
# 2019/05/21  15:02    <DIR>          .oracle_jre_usage
# 2020/01/05  11:31    <DIR>          .PyCharm2019.3
# 2019/02/17  21:35    <DIR>          .pylint.d
# 2019/04/24  17:10    <DIR>          .Rider2018.3
# 2018/10/03  21:32    <DIR>          .ssh
# 2019/04/27  14:56    <DIR>          .templateengine
# 2020/01/05  01:32    <DIR>          .VirtualBox
# 2018/09/08  00:19    <DIR>          .vscode
# 2019/04/24  17:13    <DIR>          .vsts
# 2019/07/15  22:59    <DIR>          3D Objects
# 2018/08/26  23:18    <DIR>          ansel
# 2019/07/19  22:21    <DIR>          AppData
# 2018/10/27  00:14    <DIR>          Apple
# 2020/01/06  00:54        64,368,892 article_9k.txt
# 2019/03/16  16:20    <DIR>          Autodesk
# 2019/11/29  21:04               226 BullseyeCoverageError.txt
# 2019/07/15  22:59    <DIR>          Contacts
# 2020/01/06  00:08    <DIR>          Desktop
# 2020/01/05  20:01    <DIR>          Documents
# 2019/12/01  22:59    <DIR>          Downloads
# 2018/11/29  23:23    <DIR>          fancy
# 2019/07/15  22:59    <DIR>          Favorites
# 2019/10/23  02:19    <DIR>          Funshion
# 2020/01/05  23:52    <DIR>          Google 云端硬盘
# 2018/10/05  02:21    <DIR>          IdeaProjects
# 2020/01/06  00:56            77,057 Lecture-01-Syntax-Tree-and-Language-Model.ipynb课程在线准备代码.ipynb
# 2020/01/01  23:48    <DIR>          Links
# 2019/04/06  19:41    <DIR>          maxima
# 2018/10/03  21:21               138 mercurial.ini
# 2019/07/15  22:59    <DIR>          Music
# 2018/08/27  22:54    <DIR>          OneDrive
# 2020/01/06  00:04    <DIR>          Pictures
# 2020/01/05  13:05    <DIR>          pip
# 2020/01/05  11:37    <DIR>          PycharmProjects
# 2019/07/19  22:57    <DIR>          Saved Games
# 2019/07/15  22:59    <DIR>          Searches
# 2018/08/25  20:05    <DIR>          source
# 2019/03/09  14:50    <DIR>          UIDowner
# 2020/01/06  00:53    <DIR>          Untitled Folder
# 2019/12/15  13:53                72 Untitled.ipynb
# 2019/12/17  23:27            28,050 Untitled1.ipynb
# 2020/01/05  18:44    <DIR>          Videos
# 2019/02/16  12:20    <DIR>          VirtualBox VMs
#                9 个文件     64,477,268 字节
#               56 个目录 170,263,621,632 可用字节

# %%
def cut(string): 
    return list(jieba.cut(string))

# %%
import jieba

# %%
TOKEN = []

# %%
for i, line in enumerate((open('article_9k.txt'))):
    if i % 100000 == 0: 
        print(i)
    
    # replace 10000 with a big number when you do your homework. 
    
#     if i > 10000: break    
    TOKEN += cut(line)
# Out:
# 0

# %%
with open('article_cuted.txt', 'w') as f:
    for a in TOKEN:
        f.write(a + '\n')

# %%
from functools import reduce

# %%
from operator import add, mul
mul
# Out:
# <function _operator.mul(a, b, /)>

# %%
reduce(add, [1, 2, 3, 4, 5, 8])
# Out:
# 23

# %%
[1, 2, 3] + [3, 43, 5]
# Out:
# [1, 2, 3, 3, 43, 5]

# %%
from collections import Counter

# %%
words_count = Counter(TOKEN)
words_count
# Out:
# Counter({'此外': 5515,
#          '自': 5833,
#          '本周': 714,
#          '6': 39479,
#          '月': 208041,
#          '12': 11594,
#          '日起': 1679,
#          '除': 1571,
#          '小米': 409,
#          '手机': 4002,
#          '等': 72502,
#          '15': 10271,
#          '款': 862,
#          '机型': 197,
#          '外': 3829,
#          '其余': 639,
#          '已': 24908,
#          '暂停': 1121,
#          '更新': 882,
#          '发布': 9829,
#          '含': 910,
#          '开发': 5005,
#          '版': 1196,
#          '体验版': 2,
#          '内测': 9,
#          '稳定版': 2,
#          '暂不受': 2,
#          '影响': 10674,
#          '以': 42482,
#          '确保': 3536,
#          '工程师': 624,
#          '可以': 17969,
#          '集中': 3763,
#          '全部': 4996,
#          '精力': 317,
#          '进行': 31789,
#          '系统优化': 2,
#          '工作': 25835,
#          '有人': 2650,
#          '猜测': 295,
#          '这': 31776,
#          '也': 63396,
#          '是': 131192,
#          '将': 75480,
#          '主要': 12650,
#          '用到': 52,
#          'MIUI9': 4,
#          '的': 887960,
#          '研发': 4443,
#          '之中': 850,
#          'MIUI8': 2,
#          '去年': 8079,
#          '5': 60147,
#          '距今已有': 25,
#          '一年': 4018,
#          '有余': 39,
#          '时候': 4324,
#          '更新换代': 44,
#          '了': 158660,
#          '当然': 1330,
#          '关于': 5930,
#          '确切': 90,
#          '信息': 9868,
#          '我们': 25724,
#          '还是': 7038,
#          '等待': 1134,
#          '官方消息': 19,
#          '\n': 99612,
#          '骁龙': 106,
#          '835': 40,
#          '作为': 13283,
#          '唯一': 1777,
#          '通过': 22879,
#          'Windows10': 21,
#          '桌面': 121,
#          '平台': 11034,
#          '认证': 880,
#          'ARM': 4,
#          '处理器': 181,
#          '高通': 132,
#          '强调': 3919,
#          '不会': 5132,
#          '因为': 7672,
#          '只': 6145,
#          '考虑': 3186,
#          '性能': 624,
#          '而': 23176,
#          '去': 9513,
#          '屏蔽掉': 4,
#          '小': 7956,
#          '核心': 4356,
#          '相反': 333,
#          '他们': 17438,
#          '正': 5823,
#          '联手': 526,
#          '微软': 487,
#          '找到': 2433,
#          '一种': 5222,
#          '适合': 1070,
#          '兼顾': 249,
#          '和': 164870,
#          '功耗': 34,
#          '完美': 647,
#          '方案': 3716,
#          '报道': 13457,
#          '称': 10070,
#          '已经': 16626,
#          '拿到': 1377,
#          '一些': 11913,
#          '新': 30295,
#          '源码': 4,
#          '以便': 469,
#          '更好': 3470,
#          '地': 16173,
#          '理解': 1674,
#          'biglittle': 2,
#          '架构': 315,
#          '资料': 2604,
#          '显示': 10878,
#          '一款': 831,
#          '集成': 269,
#          'CPUGPU': 2,
#          '基带': 6,
#          '蓝牙': 39,
#          'WiFi': 67,
#          'SoC': 4,
#          '比': 25160,
#          '传统': 8097,
#          'Wintel': 6,
#          '节省': 341,
#          '至少': 2945,
#          '30': 9749,
#          'PCB': 28,
#          '空间': 4654,
#          '按计划': 240,
#          '今年': 17360,
#          'Q4': 8,
#          '华硕': 19,
#          '惠普': 27,
#          '联想': 284,
#          '首发': 629,
#          '835Win10': 2,
#          '电脑': 1052,
#          '预计': 5682,
#          '均': 5953,
#          '二合一': 2,
#          '形态': 485,
#          '产品': 11738,
#          '只是': 3303,
#          '个': 29257,
#          '开始': 14106,
#          '未来': 10592,
#          '也许': 700,
#          '还': 28106,
#          '能': 15355,
#          '见到': 656,
#          '三星': 526,
#          'Exynos': 2,
#          '联发科': 30,
#          '华为': 404,
#          '麒麟': 144,
#          '澎湃': 391,
#          '进入': 12000,
#          '此前': 4166,
#          '一加': 80,
#          '3T': 2,
#          '搭载': 619,
#          '3400mAh': 2,
#          '电池': 660,
#          'DashCharge': 2,
#          '快充': 10,
#          '规格': 340,
#          '为': 71467,
#          '5V4A': 2,
#          '至于': 611,
#          '缩水': 133,
#          '可能': 13497,
#          '与': 70877,
#          '刘作': 6,
#          '虎': 300,
#          '所说': 404,
#          '要': 27321,
#          '做': 11402,
#          '市面': 8,
#          '最': 11300,
#          '轻薄': 31,
#          '大屏': 47,
#          '旗舰': 117,
#          '设定': 504,
#          '有关': 7777,
#          '按照': 6033,
#          '目前': 21482,
#          '掌握': 1623,
#          '拥有': 4087,
#          '55': 721,
#          '寸': 42,
#          '1080P': 2,
#          'AMOLED': 35,
#          '显示屏': 143,
#          '6G8GBRAM64GB128GBROM': 2,
#          '双': 1100,
#          '1600': 174,
#          '万': 4085,
#          '摄像头': 629,
#          '备货': 21,
#          '量': 1743,
#          '惊喜': 369,
#          '根据': 9000,
#          '京东': 1198,
#          '泄露': 494,
#          '起': 6090,
#          '售价': 435,
#          'xx99': 2,
#          '元': 7646,
#          '应该': 3857,
#          '在': 310967,
#          '279928992999': 2,
#          '中': 85043,
#          '某个': 251,
#          '这是': 11554,
#          '18': 8792,
#          '日': 178622,
#          '葡萄牙': 1284,
#          '中部': 1208,
#          '大': 21631,
#          '佩德罗': 91,
#          '冈': 9,
#          '地区': 12745,
#          '拍摄': 5762,
#          '被': 32852,
#          '森林': 1423,
#          '大火': 210,
#          '烧毁': 45,
#          '汽车': 6732,
#          '新华社': 143132,
#          '记者': 67881,
#          '张立': 129,
#          '云摄': 120,
#          '原': 4086,
#          '标题': 2373,
#          '44': 537,
#          '岁': 10288,
#          '女子': 4131,
#          '跑': 3022,
#          '深圳': 3774,
#          '约会': 123,
#          '网友': 2711,
#          '拒': 165,
#          '暴雨': 930,
#          '裸身': 6,
#          '奔走': 81,
#          '交警': 484,
#          '微博称': 20,
#          '昨日': 1517,
#          '清晨': 640,
#          '发现': 10925,
#          '有': 60481,
#          '一': 14452,
#          '赤裸': 23,
#          '上身': 70,
#          '行走': 627,
#          '南坪': 42,
#          '快速': 3378,
#          '上': 57644,
#          '期间': 6081,
#          '轻生': 82,
#          '年头': 158,
#          '一辅警': 4,
#          '后': 34477,
#          '赶紧': 311,
#          '其': 15757,
#          '披上': 64,
#          '黄衣': 14,
#          '并': 33980,
#          '一路': 19907,
#          '劝说': 152,
#          '她': 16301,
#          '那么': 3015,
#          '事发': 871,
#          '时': 22404,
#          '到底': 894,
#          '都': 37474,
#          '发生': 10197,
#          '些': 254,
#          '什么': 4954,
#          '呢': 2156,
#          '南': 1097,
#          '带': 3659,
#          '您': 976,
#          '一起': 6085,
#          '还原': 233,
#          '现场': 7333,
#          '龙岗': 45,
#          '大队': 1040,
#          '坂田': 12,
#          '中队': 305,
#          '辅警': 86,
#          '刘青': 60,
#          '女生': 422,
#          '一位': 3964,
#          '外表': 117,
#          '高大': 225,
#          '帅气': 64,
#          '说话': 475,
#          '略带': 32,
#          '腼腆': 74,
#          '90': 1717,
#          '青年': 4312,
#          '介绍': 8759,
#          '16': 8088,
#          '早上': 618,
#          '7': 13728,
#          '36': 1177,
#          '分': 8284,
#          '他': 46724,
#          '正在': 9567,
#          '环城': 56,
#          '南路': 136,
#          '附近': 4371,
#          '值勤': 18,
#          '接到': 1231,
#          '机动车': 591,
#          '危险': 1226,
#          '警情': 40,
#          '随后': 3167,
#          '骑着': 121,
#          '铁骑': 49,
#          '沿路': 30,
#          '寻找': 1802,
#          '大概': 539,
#          '花': 1362,
#          '十多分钟': 23,
#          '大道': 972,
#          '出口': 2689,
#          '往': 686,
#          '方向': 3139,
#          '逆行': 30,
#          '辅道': 8,
#          '该': 12415,
#          '身上': 1259,
#          '一丝不挂': 7,
#          '地逆': 4,
#          '车流': 73,
#          '行时': 10,
#          '走时': 16,
#          '停时': 4,
#          '坐时': 6,
#          '躺': 384,
#          '险象环生': 11,
#          '刘青停': 4,
#          '好': 14430,
#          '另外': 2771,
#          '一名': 9224,
#          '巡防': 29,
#          '员': 990,
#          '追': 293,
#          '上去': 180,
#          '情绪': 1299,
#          '很': 12251,
#          '低落': 35,
#          '话': 1071,
#          '不': 37990,
#          '多': 22170,
#          '尝试': 1259,
#          '交流': 6072,
#          '离开': 1901,
#          '可': 13820,
#          '愿意': 1794,
#          '接受': 7094,
#          '继续': 8713,
#          '缓慢': 425,
#          '地往': 14,
#          '快速路': 104,
#          '主干道': 74,
#          '走': 5855,
#          '此时': 624,
#          '路边': 336,
#          '聚集': 942,
#          '市民': 4241,
#          '围观': 194,
#          '为了': 6078,
#          '刺激': 699,
#          '一边': 1238,
#          '盯': 167,
#          '着': 17387,
#          '驱赶': 50,
#          '群众': 6159,
#          '从': 37002,
#          '警方': 5332,
#          '提供': 15090,
#          '一份': 2312,
#          '视频': 3668,
#          '了解': 9467,
#          '到': 38447,
#          '25': 7442,
#          '出现': 10504,
#          '坂雪岗': 8,
#          '监控': 1288,
#          '穿着': 449,
#          '白色': 653,
#          '内裤': 44,
#          '沿着': 444,
#          '当时': 4395,
#          '正值': 487,
#          '上班': 462,
#          '高峰期': 222,
#          '十字路口': 109,
#          '排起': 37,
#          '长队': 82,
#          '当': 4238,
#          '路上': 1118,
#          '纷纷': 1779,
#          '驻足': 162,
#          '观望': 400,
#          '不少': 5751,
#          '车辆': 2816,
#          '放慢': 55,
#          '速度': 2280,
#          '但': 31114,
#          '停下': 113,
#          '脚步': 397,
#          '依然': 2792,
#          '行进': 282,
#          '中间': 583,
#          '一辆': 1578,
#          '货车': 754,
#          '挡住': 93,
#          '镜头': 476,
#          '但是': 5676,
#          '再次出现': 81,
#          '没': 3592,
#          '穿': 997,
#          '全身': 203,
#          '裸露': 146,
#          '朝着': 291,
#          '周围': 782,
#          '没有': 18998,
#          '人': 36911,
#          '尾随': 52,
#          '或者': 4597,
#          '上前': 221,
#          '劝止': 4,
#          '大清早': 14,
#          '看到': 5751,
#          '这样': 7847,
#          '情况': 12526,
#          '恐怕': 391,
#          '大家': 4548,
#          '办法': 2471,
#          '淡定': 72,
#          '面对': 3076,
#          '这一': 5847,
#          '表示': 28443,
#          '根本': 1308,
#          '不敢': 646,
#          '看': 7231,
#          '心里': 831,
#          '挺': 635,
#          '别扭': 23,
#          '感觉': 2005,
#          '尴尬': 405,
#          '跟随': 566,
#          '作出': 3146,
#          '让': 23310,
#          '意想不到': 75,
#          '举动': 350,
#          '突然': 1437,
#          '靠近': 458,
#          '护栏': 109,
#          '上面': 502,
#          '跳下去': 17,
#          '赶忙': 29,
#          '冲上去': 33,
#          '拉住': 7,
#          '手': 1078,
#          '控制': 3452,
#          '住': 2007,
#          '远离': 390,
#          '碍于': 32,
#          '穿衣服': 29,
#          '刘青递': 4,
#          '衣服': 547,
#          '把': 15111,
#          '扔': 242,
#          '排水沟': 26,
#          '里': 11921,
#          '往前走': 52,
#          '只能': 2183,
#          '紧紧': 239,
#          '拉': 1781,
#          '一只': 1517,
#          '跟': 3054,
#          '后面': 464,
#          '一路上': 333,
#          '耐心': 476,
#          '开导': 33,
#          '安慰': 177,
#          '听到': 801,
#          '不断': 7770,
#          '重复': 455,
#          '一句': 785,
#          '要是': 249,
#          '你': 10086,
#          '遭遇': 2052,
#          '我': 28081,
#          '事': 2446,
#          '会': 23322,
#          '不时': 369,
#          '试图': 1095,
#          '挣脱': 34,
#          '手要': 14,
#          '冲向': 130,
#          '往下跳': 7,
#          '就': 35221,
#          '牵': 83,
#          '天': 3670,
#          '下起': 7,
#          '大暴雨': 268,
#          '雨大': 4,
#          '连': 1743,
#          '眼睛': 577,
#          '睁不开': 9,
#          '说': 45720,
#          '瞬间': 698,
#          '雨': 391,
#          '透': 72,
#          '帮助': 6205,
#          '冒': 218,
#          '大雨': 314,
#          '四十分钟': 8,
#          '吧': 1852,
#          '来说': 3979,
#          '想': 4989,
#          '回家': 996,
#          '然后': 1688,
#          '递过来': 16,
#          '微博上': 160,
#          '照片': 52614,
#          '披着': 4,
#          '小心翼翼': 117,
#          '旁边': 435,
#          '场景': 1043,
#          '南平': 79,
#          '下来': 1084,
#          '带到': 327,
#          '派出所': 947,
#          '那': 3541,
#          '姑娘': 555,
#          '什么样': 541,
#          '事情': 2093,
#          '才': 5286,
#          '据': 12887,
#          '透露': 2185,
#          '姓': 92,
#          '陈系': 4,
#          '湖北': 2996,
#          '家属': 929,
#          '反映': 2058,
#          '其有': 15,
#          '精神病': 76,
#          '史': 520,
#          '三天': 501,
#          '前': 15599,
#          '陈某': 419,
#          '老家': 299,
#          '来': 13920,
#          '受挫': 76,
#          '导致': 5101,
#          '异常': 580,
#          '遂': 211,
#          '产生': 4079,
#          '念头': 128,
#          '送往': 513,
#          '某': 2626,
#          '医院': 5205,
#          '治疗': 2506,
#          '大大': 525,
#          '君': 228,
#          '希望': 9462,
#          '早点': 52,
#          '康复': 646,
#          '其实': 2588,
#          '真爱': 27,
#          '到来': 1264,
#          '存在': 6815,
#          '年龄': 1081,
#          '限制': 2204,
#          '你们': 1027,
#          '因': 5772,
#          '善良': 112,
#          '原因': 4780,
#          '一众': 66,
#          '暖': 280,
#          '男点': 4,
#          'ZAN': 4,
#          '弓常': 4,
#          'yan': 5,
#          '桦': 16,
#          '问': 1313,
#          '这个': 11738,
#          '哥哥': 401,
#          '女票': 4,
#          '吗': 2625,
#          '原谅': 35,
#          '一辈子': 296,
#          '浪荡': 4,
#          '不羁': 27,
#          '爱': 1849,
#          '萨摩耶': 4,
#          '过不去': 23,
#          '嘛': 141,
#          '想想': 114,
#          '自己': 18117,
#          '家人': 1703,
#          '同时': 13844,
#          '感谢': 816,
#          '蜀黍': 24,
#          '火心': 4,
#          '聆听': 226,
#          '心灵': 281,
#          '点赞': 420,
#          '中華云盾': 4,
#          '警察': 2143,
#          '就是': 10921,
#          '需时': 5,
#          '申出': 4,
#          '援手': 68,
#          'Tomchlee': 4,
#          '帅': 35,
#          'SJ': 4,
#          '李赫海': 4,
#          'i': 39,
#          '木有': 8,
#          '男子': 4613,
#          '迷奸': 2,
#          '拍': 1014,
#          '418': 44,
#          '女方': 62,
#          '20': 14092,
#          '50': 4210,
#          '号': 7767,
#          '上午': 2806,
#          '淮安市': 80,
#          '涟水县': 3,
#          '公安局': 1081,
#          '刑警大队': 25,
#          '一个': 28704,
#          '奇怪': 168,
#          '报警': 711,
#          '电话': 1823,
#          '言语': 117,
#          '不清': 75,
#          '声称': 453,
#          '遭到': 1075,
#          '侵害': 402,
#          '几个': 1806,
#          '关键词': 1551,
#          '令': 1568,
#          '民警': 2081,
#          '紧张': 1451,
#          '起来': 3406,
#          '受到': 4644,
#          'A股': 3821,
#          '纳入': 3542,
#          'MSCI': 2478,
#          '指数': 6092,
#          '利好': 737,
#          '消息': 5029,
#          '市场': 27096,
#          '周三': 335,
#          '再度': 1047,
#          '上演': 1475,
#          '龙马': 41,
#          '行情': 1328,
#          '周四': 250,
#          '金融股': 226,
#          '白马股': 207,
#          '表现': 4041,
#          '喜人': 63,
#          '尾盘': 377,
#          '跳水': 768,
#          '之后': 6503,
#          '仅': 4020,
#          '金融': 7800,
#          '板块': 2312,
#          '仍': 7334,
#          '维系': 71,
#          '红盘': 32,
#          '状态': 2506,
#          '分析': 5264,
#          '人士': 4461,
#          '认为': 14935,
#          '受益': 973,
#          '于': 20792,
#          '低': 2963,
#          '估值': 907,
#          '重获': 101,
#          '资金': 9464,
#          '青睐': 554,
#          '存量': 560,
#          '博弈': 353,
#          '格局': 1637,
#          '下': 21867,
#          '风格': 1090,
#          '交替': 136,
#          '震荡': 1209,
#          '料': 166,
#          '延续': 1538,
#          '流动性': 1596,
#          '改善': 3283,
#          '经济': 26676,
#          '悲观': 145,
#          '预期': 3622,
#          '修正': 164,
#          '有助于': 1367,
#          '支撑': 2743,
#          '继而': 112,
#          '大盘': 685,
#          '逐步': 2374,
#          '向': 18581,
#          '一九': 2,
#          '再现': 433,
#          '未能': 1293,
#          '上行': 656,
#          '态势': 1515,
#          '两市': 761,
#          '成交': 2347,
#          '小幅': 716,
#          '放量': 259,
#          '29': 5010,
#          '中信': 205,
#          '一级': 756,
#          '行业': 9236,
#          '收盘': 994,
#          '银行': 8236,
#          '非银行': 72,
#          '两个': 5401,
#          '收红': 57,
#          '分别': 7082,
#          '上涨': 5375,
#          '180': 429,
#          '020': 56,
#          '二级': 634,
#          '来看': 4029,
#          '股份制': 181,
#          '城商行': 80,
#          '涨幅': 3222,
#          '最高': 4435,
#          '达到': 7070,
#          '222': 230,
#          '国有银行': 52,
#          '082': 10,
#          '信托': 611,
#          '及其': 2236,
#          '064': 9,
#          '保险': 2232,
#          '034': 25,
#          '证券': 2496,
#          '006': 46,
#          '成分股': 233,
#          '中共': 674,
#          '21': 8575,
#          '其中': 14037,
#          '招商银行': 154,
#          '最大': 7520,
#          '666': 47,
#          '贵阳': 951,
#          '365': 113,
#          '上海银行': 45,
#          '华夏银行': 82,
#          '浦发银行': 63,
#          '兴业银行': 99,
#          '超过': 9415,
#          '150': 793,
#          '17': 7722,
#          '个股': 1281,
#          '安信': 93,
#          '中国': 82215,
#          '太保': 55,
#          '居前': 537,
#          '两名': 1858,
#          '457': 32,
#          '304': 35,
#          '西水股份': 8,
#          '华安': 62,
#          '人寿': 164,
#          '新华': 6553,
#          '2': 27212,
#          '相对而言': 100,
#          '券商': 1068,
#          '股多': 2,
#          '下跌': 3890,
#          '近期': 3495,
#          '对': 63391,
#          '消息面': 89,
#          '宣布': 6220,
#          '2018': 1717,
#          '年': 139077,
#          '新兴': 1808,
#          '占': 6702,
#          '群体': 1526,
#          '国金': 48,
#          '李立峰': 14,
#          '团队': 5254,
#          '指出': 6503,
#          '最新': 2857,
#          '包含': 777,
#          '剔除': 150,
#          '中等': 192,
#          '市值': 876,
#          '非': 3498,
#          '互联互通': 1300,
#          '交易': 5449,
#          '股票': 1879,
#          '以及': 13681,
#          '停牌': 496,
#          '标的': 793,
#          '由于': 7091,
#          '很多': 7621,
#          'A': 1197,
#          'H股': 103,
#          'MSCIEM': 12,
#          '权重': 417,
#          '由': 15800,
#          '05': 878,
#          '上升': 2750,
#          '073': 119,
#          '4011': 2,
#          '泛': 137,
#          '消费': 4104,
#          '次之': 25,
#          '2426': 4,
#          '涵盖': 820,
#          '大部分': 1678,
#          '权重股': 158,
#          '动态': 1027,
#          '加入': 2646,
#          '指': 2119,
#          '比高': 70,
#          '金融公司': 61,
#          '增加': 7164,
#          '近一半': 92,
#          '其他': 8386,
#          '稀释': 59,
#          '尽管': 2660,
#          '事件': 6119,
#          '短期': 1737,
#          '有所': 2140,
#          '提振对': 2,
#          '中长期': 493,
#          '海外': 3516,
#          '增量': 564,
#          '升温': 404,
#          '短期内': 372,
#          '尚': 685,
#          '不能': 5687,
#          '有效': 4876,
#          '放大': 300,
#          '独': 70,
#          '乐乐': 18,
#          '情景': 251,
#          '难以': 1668,
#          '持续': 8752,
#          '难': 1741,
#          '改变': 3506,
#          '光大': 78,
#          '并未': 1592,
#          '引起': 1892,
#          '太大': 163,
#          '热情': 1055,
#          '成交量': 850,
#          '较为': 1330,
#          '平淡': 99,
#          '较大': 2203,
#          '变化': 3872,
#          '成长': 2237,
#          '股': 1285,
#          '题材股': 96,
#          '全天': 472,
#          '低迷': 563,
#          '表明': 1750,
#          '很少': 649,
#          '不同': 6877,
#          '之间': 4719,
#          '腾挪': 35,
#          '跷跷板': 35,
#          '使得': 1518,
#          '难有': 80,
#          '突破': 3835,
#          '中期': 586,
#          '依旧': 850,
#          '偏空': 18,
#          '维持': 1723,
#          '虽然': 5691,
#          '至今': 2016,
#          '夏普': 246,
#          '智能手机': 412,
#          '无法': 3690,
#          '排得': 4,
#          '完全': 3280,
#          '没落': 11,
#          '并于': 251,
#          '2013': 1940,
#          '退出': 1975,
#          '3': 29499,
#          '月份': 4611,
#          '官方': 1727,
#          '回归': 1219,
#          '预示': 187,
#          '很快': 1274,
#          '新机': 44,
#          '登场': 305,
#          '第一款': 71,
#          '登陆': 521,
#          '又': 11557,
#          '怎么样': 192,
#          '近日': 5540,
#          '型号': 298,
#          'FS8016': 2,
#          '神秘': 473,
#          '悄然': 331,
#          'GeekBench': 2,
#          '分库': 22,
#          '相关': 15376,
#          '这款': 301,
#          '机子': 10,
#          '并非': 1425,
#          '定位': 1433,
#          '所': 7970,
#          '660': 35,
#          '配备': 643,
#          '4GB': 20,
#          '内存': 132,
#          '最受': 247,
#          '瞩目': 155,
#          '芯片': 762,
#          '之一': 6852,
#          '采用': 2512,
#          '14': 8211,
#          '纳米': 172,
#          '工艺': 896,
#          '八个': 136,
#          'Kryo260': 2,
#          '设计': 6709,
#          'Adreno512GPU': 2,
#          'X12LTE': 2,
#          '调制解调器': 11,
#          '当前': 3917,
#          '市面上': 126,
#          '只有': 4583,
#          '上市': 2644,
#          '销售': 5311,
#          'OPPOR11': 14,
#          '核新能': 2,
#          '820': 44,
#          '强': 2763,
#          '单核': 10,
#          '改进': 758,
#          '明显': 4985,
#          '所以': 3599,
#          '放在': 993,
#          '变成': 1629,
#          '高端': 2184,
#          '机': 602,
#          '不过': 5543,
#          'OPPO': 40,
#          '签署': 2863,
#          '排他性': 22,
#          '协议': 5256,
#          '独占': 36,
#          '两三个': 78,
#          '时间': 14217,
#          '既然': 257,
#          '测试': 1735,
#          '说明': 1837,
#          '只要': 2122,
#          '时期': 2304,
#          '一过': 11,
#          '新品': 700,
#          '之前': 3532,
#          '曝光': 987,
#          '渲染': 96,
#          '图': 1534,
#          '竞争': 2136,
#          '优势': 5439,
#          '全面': 7603,
#          '屏': 147,
#          '推出': 3631,
#          '全球': 12645,
#          '首款': 236,
#          'EDGEST302SH': 2,
#          '多达': 315,
#          '28': 6219,
#          '媒体': 11332,
#          '沟通': 2055,
#          '会上': 1083,
#          '罗忠生': 2,
#          '我敢': 6,
#          '打赌': 4,
#          '在座': 37,
#          ...})

# %%
words_count.most_common(10)
# Out:
# [('的', 887960),
#  ('n', 382038),
#  ('在', 310967),
#  ('月', 208041),
#  ('日', 178622),
#  ('和', 164870),
#  ('了', 158660),
#  ('新华社', 143132),
#  ('年', 139077),
#  ('是', 131192)]

# %%
frequiences = [f for w, f in words_count.most_common(10)]
frequiences
# Out:
# [887960,
#  382038,
#  310967,
#  208041,
#  178622,
#  164870,
#  158660,
#  143132,
#  139077,
#  131192]

# %%
x = [i for i in range(100)]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, frequiences)

# %%
import numpy as np

# %%
plt.plot(x, np.log(frequiences))

# %%
len(TOKEN)
# Out:
# 21312110

# %%
words_count['的']
# Out:
# 887960

# %%
## TOKEN 里是分词后的数组

# %%
TOKEN
# Out:
# ['此外',
#  '自',
#  '本周',
#  '6',
#  '月',
#  '12',
#  '日起',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  '其余',
#  '机型',
#  '已',
#  '暂停',
#  '更新',
#  '发布',
#  '含',
#  '开发',
#  '版',
#  '体验版',
#  '内测',
#  '稳定版',
#  '暂不受',
#  '影响',
#  '以',
#  '确保',
#  '工程师',
#  '可以',
#  '集中',
#  '全部',
#  '精力',
#  '进行',
#  '系统优化',
#  '工作',
#  '有人',
#  '猜测',
#  '这',
#  '也',
#  '是',
#  '将',
#  '精力',
#  '主要',
#  '用到',
#  'MIUI9',
#  '的',
#  '研发',
#  '之中',
#  'MIUI8',
#  '去年',
#  '5',
#  '月',
#  '发布',
#  '距今已有',
#  '一年',
#  '有余',
#  '也',
#  '是',
#  '时候',
#  '更新换代',
#  '了',
#  '当然',
#  '关于',
#  'MIUI9',
#  '的',
#  '确切',
#  '信息',
#  '我们',
#  '还是',
#  '等待',
#  '官方消息',
#  '\n',
#  '骁龙',
#  '835',
#  '作为',
#  '唯一',
#  '通过',
#  'Windows10',
#  '桌面',
#  '平台',
#  '认证',
#  '的',
#  'ARM',
#  '处理器',
#  '高通',
#  '强调',
#  '不会',
#  '因为',
#  '只',
#  '考虑',
#  '性能',
#  '而',
#  '去',
#  '屏蔽掉',
#  '小',
#  '核心',
#  '相反',
#  '他们',
#  '正',
#  '联手',
#  '微软',
#  '找到',
#  '一种',
#  '适合',
#  '桌面',
#  '平台',
#  '的',
#  '兼顾',
#  '性能',
#  '和',
#  '功耗',
#  '的',
#  '完美',
#  '方案',
#  '报道',
#  '称',
#  '微软',
#  '已经',
#  '拿到',
#  '了',
#  '一些',
#  '新',
#  '的',
#  '源码',
#  '以便',
#  'Windows10',
#  '更好',
#  '地',
#  '理解',
#  'biglittle',
#  '架构',
#  '资料',
#  '显示',
#  '骁龙',
#  '835',
#  '作为',
#  '一款',
#  '集成',
#  '了',
#  'CPUGPU',
#  '基带',
#  '蓝牙',
#  'WiFi',
#  '的',
#  'SoC',
#  '比',
#  '传统',
#  '的',
#  'Wintel',
#  '方案',
#  '可以',
#  '节省',
#  '至少',
#  '30',
#  '的',
#  'PCB',
#  '空间',
#  '按计划',
#  '今年',
#  'Q4',
#  '华硕',
#  '惠普',
#  '联想',
#  '将',
#  '首发',
#  '骁龙',
#  '835Win10',
#  '电脑',
#  '预计',
#  '均',
#  '是',
#  '二合一',
#  '形态',
#  '的',
#  '产品',
#  '当然',
#  '高通',
#  '骁龙',
#  '只是',
#  '个',
#  '开始',
#  '未来',
#  '也许',
#  '还',
#  '能',
#  '见到',
#  '三星',
#  'Exynos',
#  '联发科',
#  '华为',
#  '麒麟',
#  '小米',
#  '澎湃',
#  '等',
#  '进入',
#  'Windows10',
#  '桌面',
#  '平台',
#  '\n',
#  '此前',
#  '的',
#  '一加',
#  '3T',
#  '搭载',
#  '的',
#  '是',
#  '3400mAh',
#  '电池',
#  'DashCharge',
#  '快充',
#  '规格',
#  '为',
#  '5V4A',
#  '至于',
#  '电池',
#  '缩水',
#  '可能',
#  '与',
#  '刘作',
#  '虎',
#  '所说',
#  '一加',
#  '手机',
#  '5',
#  '要',
#  '做',
#  '市面',
#  '最',
#  '轻薄',
#  '大屏',
#  '旗舰',
#  '的',
#  '设定',
#  '有关',
#  '按照',
#  '目前',
#  '掌握',
#  '的',
#  '资料',
#  '一加',
#  '手机',
#  '5',
#  '拥有',
#  '55',
#  '寸',
#  '1080P',
#  '三星',
#  'AMOLED',
#  '显示屏',
#  '6G8GBRAM64GB128GBROM',
#  '双',
#  '1600',
#  '万',
#  '摄像头',
#  '备货',
#  '量',
#  '惊喜',
#  '根据',
#  '京东',
#  '泄露',
#  '的',
#  '信息',
#  '一加',
#  '5',
#  '起',
#  '售价',
#  '是',
#  'xx99',
#  '元',
#  '应该',
#  '是',
#  '在',
#  '279928992999',
#  '中',
#  '的',
#  '某个',
#  '\n',
#  '这是',
#  '6',
#  '月',
#  '18',
#  '日',
#  '在',
#  '葡萄牙',
#  '中部',
#  '大',
#  '佩德罗',
#  '冈',
#  '地区',
#  '拍摄',
#  '的',
#  '被',
#  '森林',
#  '大火',
#  '烧毁',
#  '的',
#  '汽车',
#  '新华社',
#  '记者',
#  '张立',
#  '云摄',
#  '\n',
#  '原',
#  '标题',
#  '44',
#  '岁',
#  '女子',
#  '跑',
#  '深圳',
#  '约会',
#  '网友',
#  '被',
#  '拒',
#  '暴雨',
#  '中',
#  '裸身',
#  '奔走',
#  '深圳',
#  '交警',
#  '微博称',
#  '昨日',
#  '清晨',
#  '交警',
#  '发现',
#  '有',
#  '一',
#  '女子',
#  '赤裸',
#  '上身',
#  '行走',
#  '在',
#  '南坪',
#  '快速',
#  '上',
#  '期间',
#  '还',
#  '起',
#  '了',
#  '轻生',
#  '年头',
#  '一辅警',
#  '发现',
#  '后',
#  '赶紧',
#  '为',
#  '其',
#  '披上',
#  '黄衣',
#  '并',
#  '一路',
#  '劝说',
#  '她',
#  '那么',
#  '事发',
#  '时',
#  '到底',
#  '都',
#  '发生',
#  '了',
#  '些',
#  '什么',
#  '呢',
#  '南',
#  '都',
#  '记者',
#  '带',
#  '您',
#  '一起',
#  '还原',
#  '现场',
#  '南',
#  '都',
#  '记者',
#  '在',
#  '龙岗',
#  '大队',
#  '坂田',
#  '中队',
#  '见到',
#  '了',
#  '辅警',
#  '刘青',
#  '发现',
#  '女生',
#  '的',
#  '辅警',
#  '一位',
#  '外表',
#  '高大',
#  '帅气',
#  '说话',
#  '略带',
#  '些',
#  '腼腆',
#  '的',
#  '90',
#  '后',
#  '青年',
#  '刘青',
#  '介绍',
#  '6',
#  '月',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '36',
#  '分',
#  '他',
#  '正在',
#  '环城',
#  '南路',
#  '附近',
#  '值勤',
#  '接到',
#  '中队',
#  '关于',
#  '一位',
#  '女子',
#  '裸身',
#  '进入',
#  '机动车',
#  '可能',
#  '有',
#  '危险',
#  '的',
#  '警情',
#  '随后',
#  '骑着',
#  '小',
#  '铁骑',
#  '开始',
#  '沿路',
#  '寻找',
#  '大概',
#  '花',
#  '了',
#  '十多分钟',
#  '在',
#  '南坪',
#  '大道',
#  '坂田',
#  '出口',
#  '往',
#  '龙岗',
#  '方向',
#  '的',
#  '逆行',
#  '辅道',
#  '上',
#  '发现',
#  '该',
#  '女子',
#  '女子',
#  '身上',
#  '一丝不挂',
#  '地逆',
#  '车流',
#  '而',
#  '行时',
#  '走时',
#  '停时',
#  '坐时',
#  '躺',
#  '险象环生',
#  '刘青停',
#  '好',
#  '小',
#  '铁骑',
#  '和',
#  '另外',
#  '一名',
#  '巡防',
#  '员',
#  '追',
#  '了',
#  '上去',
#  '发现',
#  '女子',
#  '的',
#  '情绪',
#  '很',
#  '低落',
#  '话',
#  '不',
#  '多',
#  '刘青',
#  '尝试',
#  '和',
#  '女子',
#  '交流',
#  '劝说',
#  '女子',
#  '离开',
#  '可',
#  '女子',
#  '并',
#  '不',
#  '愿意',
#  '接受',
#  '继续',
#  '缓慢',
#  '地往',
#  '南坪',
#  '快速路',
#  '的',
#  '主干道',
#  '上',
#  '走',
#  '去',
#  '此时',
#  '路边',
#  '上',
#  '已经',
#  '聚集',
#  '了',
#  '很',
#  '市民',
#  '围观',
#  '为了',
#  '不',
#  '刺激',
#  '女子',
#  '的',
#  '情绪',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '一边',
#  '盯',
#  '着',
#  '女子',
#  '一边',
#  '驱赶',
#  '着',
#  '围观',
#  '的',
#  '群众',
#  '现场',
#  '还原',
#  '从',
#  '警方',
#  '提供',
#  '的',
#  '一份',
#  '视频',
#  '了解',
#  '到',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '25',
#  '分',
#  '女子',
#  '出现',
#  '在',
#  '坂雪岗',
#  '大道',
#  '与',
#  '环城',
#  '南路',
#  '的',
#  '监控',
#  '视频',
#  '中',
#  '此时',
#  '女子',
#  '还',
#  '穿着',
#  '白色',
#  '的',
#  '内裤',
#  '正',
#  '沿着',
#  '坂雪岗',
#  '大道',
#  '往',
#  '南坪',
#  '快速',
#  '的',
#  '方向',
#  '缓慢',
#  '地',
#  '走',
#  '着',
#  '当时',
#  '正值',
#  '上班',
#  '高峰期',
#  '十字路口',
#  '的',
#  '车流',
#  '已经',
#  '排起',
#  '了',
#  '长队',
#  '当',
#  '女子',
#  '出现',
#  '时',
#  '路上',
#  '的',
#  '市民',
#  '纷纷',
#  '驻足',
#  '观望',
#  '不少',
#  '车辆',
#  '也',
#  '放慢',
#  '了',
#  '速度',
#  '但',
#  '女子',
#  '并',
#  '不',
#  '为',
#  '市民',
#  '观望',
#  '停下',
#  '脚步',
#  '依然',
#  '缓慢',
#  '走',
#  '着',
#  '当',
#  '女子',
#  '行进',
#  '到',
#  '十字路口',
#  '中间',
#  '时',
#  '一辆',
#  '大',
#  '货车',
#  '挡住',
#  '了',
#  '镜头',
#  '但是',
#  '当',
#  '女子',
#  '再次出现',
#  '镜头',
#  '时',
#  '可以',
#  '发现',
#  '女子',
#  '已经',
#  '没',
#  '穿',
#  '内裤',
#  '了',
#  '全身',
#  '裸露',
#  '继续',
#  '朝着',
#  '南坪',
#  '快速',
#  '方向',
#  '走',
#  '去',
#  '记者',
#  '发现',
#  '视频',
#  '中',
#  '女子',
#  '周围',
#  '并',
#  '没有',
#  '人',
#  '尾随',
#  '或者',
#  '上前',
#  '劝止',
#  '的',
#  '市民',
#  '一',
#  '大清早',
#  '路上',
#  '看到',
#  '这样',
#  '的',
#  '情况',
#  '恐怕',
#  '大家',
#  '都',
#  '没',
#  '办法',
#  '淡定',
#  '面对',
#  '这一',
#  '情况',
#  '刘青',
#  '表示',
#  '一',
#  '开始',
#  '根本',
#  '不敢',
#  '看',
#  '她',
#  '心里',
#  '挺',
#  '别扭',
#  '感觉',
#  '很',
#  '尴尬',
#  '但',
#  '当',
#  '刘青',
#  '跟随',
#  '女子',
#  '上',
#  '了',
#  '南坪',
#  '快速路',
#  '主干道',
#  '时',
#  '女子',
#  '作出',
#  '了',
#  '让',
#  '人',
#  '意想不到',
#  '的',
#  '举动',
#  '她',
#  '突然',
#  '靠近',
#  '护栏',
#  '要',
#  '从',
#  '上面',
#  '跳下去',
#  '刘青',
#  '赶忙',
#  '冲上去',
#  '拉住',
#  '了',
#  '女子',
#  '的',
#  '手',
#  '将',
#  '其',
#  '控制',
#  '住',
#  '并',
#  '远离',
#  '护栏',
#  '碍于',
#  '女子',
#  '没有',
#  '穿衣服',
#  '刘青递',
#  '上',
#  '衣服',
#  '女子',
#  '没',
#  '接受',
#  '还',
#  '把',
#  '衣服',
#  '扔',
#  '到',
#  '排水沟',
#  '里',
#  '继续',
#  '往前走',
#  '没',
#  '办法',
#  '刘青',
#  '只能',
#  '紧紧',
#  '拉',
#  '着',
#  '她',
#  '的',
#  '一只',
#  '手',
#  '跟',
#  '在',
#  '后面',
#  '刘青',
#  '一路上',
#  '耐心',
#  '地',
#  '开导',
#  '安慰',
#  '她',
#  '但',
#  '只',
#  '听到',
#  '她',
#  '不断',
#  '地',
#  '重复',
#  '着',
#  '一句',
#  '话',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '的',
#  '期间',
#  '她',
#  '还',
#  '不时',
#  '试图',
#  '挣脱',
#  '刘青',
#  '的',
#  '手要',
#  '冲向',
#  '护栏',
#  '往下跳',
#  '就',
#  '这样',
#  '我',
#  '被',
#  '牵',
#  '着',
#  '走',
#  '了',
#  '大概',
#  '十多分钟',
#  '天',
#  '突然',
#  '下起',
#  '了',
#  '大暴雨',
#  '雨大',
#  '的',
#  '连',
#  '眼睛',
#  '都',
#  '睁不开',
#  '刘青',
#  '继续',
#  '说',
#  '着',
#  '瞬间',
#  '他们',
#  '就',
#  '被',
#  '雨',
#  '透',
#  '了',
#  '但',
#  '女子',
#  '依然',
#  '不',
#  '愿意',
#  '接受',
#  '刘青',
#  '的',
#  '帮助',
#  '就',
#  '继续',
#  '冒',
#  '着',
#  '大雨',
#  '往前走',
#  '大概',
#  '走',
#  '了',
#  '有',
#  '四十分钟',
#  '吧',
#  '女子',
#  '突然',
#  '停下',
#  '来说',
#  '我',
#  '想',
#  '回家',
#  '了',
#  '然后',
#  '女子',
#  '也',
#  '接受',
#  '了',
#  '刘青',
#  '递过来',
#  '的',
#  '小',
#  '黄衣',
#  '就',
#  '出现',
#  '了',
#  '深圳',
#  '微博上',
#  '的',
#  '照片',
#  '女子',
#  '披着',
#  '小',
#  '黄衣',
#  '刘青',
#  '小心翼翼',
#  '地',
#  '在',
#  '旁边',
#  '走',
#  '着',
#  '的',
#  '场景',
#  '从',
#  '南平',
#  '快速',
#  '下来',
#  '后',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '将',
#  '女子',
#  '带到',
#  '了',
#  '附近',
#  '的',
#  '坂田',
#  '派出所',
#  '那',
#  '姑娘',
#  '到底',
#  '是',
#  '遭遇',
#  '了',
#  '什么样',
#  '的',
#  '事情',
#  '才',
#  '会',
#  '说',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '据',
#  '警方',
#  '透露',
#  '该',
#  '女子',
#  '姓',
#  '陈系',
#  '湖北',
#  '人',
#  '今年',
#  '44',
#  '岁',
#  '据',
#  '家属',
#  '反映',
#  '其有',
#  '精神病',
#  '史',
#  '三天',
#  '前',
#  '陈某',
#  '从',
#  '老家',
#  '来',
#  '深圳',
#  '约会',
#  '网友',
#  '但',
#  '约会',
#  '受挫',
#  '导致',
#  '情绪',
#  '异常',
#  '女子',
#  '遂',
#  '产生',
#  '轻生',
#  '念头',
#  ...]

# %%
#计算一个词的独立概率

# %%
def prob_1(word):
    return words_count[word] / len(TOKEN)

# %%
prob_1('我们')
# Out:
# 0.0012070132896273528

# %%
prob_1('的')
# Out:
# 0.04166457474177827

# %%
TOKEN[:10]
# Out:
# ['此外', '自', '本周', '6', '月', '12', '日起', '除', '小米', '手机']

# %%
TOKEN = [str(t) for t in TOKEN]

# %%
TOKEN
# Out:
# ['此外',
#  '自',
#  '本周',
#  '6',
#  '月',
#  '12',
#  '日起',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  '其余',
#  '机型',
#  '已',
#  '暂停',
#  '更新',
#  '发布',
#  '含',
#  '开发',
#  '版',
#  '体验版',
#  '内测',
#  '稳定版',
#  '暂不受',
#  '影响',
#  '以',
#  '确保',
#  '工程师',
#  '可以',
#  '集中',
#  '全部',
#  '精力',
#  '进行',
#  '系统优化',
#  '工作',
#  '有人',
#  '猜测',
#  '这',
#  '也',
#  '是',
#  '将',
#  '精力',
#  '主要',
#  '用到',
#  'MIUI9',
#  '的',
#  '研发',
#  '之中',
#  'MIUI8',
#  '去年',
#  '5',
#  '月',
#  '发布',
#  '距今已有',
#  '一年',
#  '有余',
#  '也',
#  '是',
#  '时候',
#  '更新换代',
#  '了',
#  '当然',
#  '关于',
#  'MIUI9',
#  '的',
#  '确切',
#  '信息',
#  '我们',
#  '还是',
#  '等待',
#  '官方消息',
#  '\n',
#  '骁龙',
#  '835',
#  '作为',
#  '唯一',
#  '通过',
#  'Windows10',
#  '桌面',
#  '平台',
#  '认证',
#  '的',
#  'ARM',
#  '处理器',
#  '高通',
#  '强调',
#  '不会',
#  '因为',
#  '只',
#  '考虑',
#  '性能',
#  '而',
#  '去',
#  '屏蔽掉',
#  '小',
#  '核心',
#  '相反',
#  '他们',
#  '正',
#  '联手',
#  '微软',
#  '找到',
#  '一种',
#  '适合',
#  '桌面',
#  '平台',
#  '的',
#  '兼顾',
#  '性能',
#  '和',
#  '功耗',
#  '的',
#  '完美',
#  '方案',
#  '报道',
#  '称',
#  '微软',
#  '已经',
#  '拿到',
#  '了',
#  '一些',
#  '新',
#  '的',
#  '源码',
#  '以便',
#  'Windows10',
#  '更好',
#  '地',
#  '理解',
#  'biglittle',
#  '架构',
#  '资料',
#  '显示',
#  '骁龙',
#  '835',
#  '作为',
#  '一款',
#  '集成',
#  '了',
#  'CPUGPU',
#  '基带',
#  '蓝牙',
#  'WiFi',
#  '的',
#  'SoC',
#  '比',
#  '传统',
#  '的',
#  'Wintel',
#  '方案',
#  '可以',
#  '节省',
#  '至少',
#  '30',
#  '的',
#  'PCB',
#  '空间',
#  '按计划',
#  '今年',
#  'Q4',
#  '华硕',
#  '惠普',
#  '联想',
#  '将',
#  '首发',
#  '骁龙',
#  '835Win10',
#  '电脑',
#  '预计',
#  '均',
#  '是',
#  '二合一',
#  '形态',
#  '的',
#  '产品',
#  '当然',
#  '高通',
#  '骁龙',
#  '只是',
#  '个',
#  '开始',
#  '未来',
#  '也许',
#  '还',
#  '能',
#  '见到',
#  '三星',
#  'Exynos',
#  '联发科',
#  '华为',
#  '麒麟',
#  '小米',
#  '澎湃',
#  '等',
#  '进入',
#  'Windows10',
#  '桌面',
#  '平台',
#  '\n',
#  '此前',
#  '的',
#  '一加',
#  '3T',
#  '搭载',
#  '的',
#  '是',
#  '3400mAh',
#  '电池',
#  'DashCharge',
#  '快充',
#  '规格',
#  '为',
#  '5V4A',
#  '至于',
#  '电池',
#  '缩水',
#  '可能',
#  '与',
#  '刘作',
#  '虎',
#  '所说',
#  '一加',
#  '手机',
#  '5',
#  '要',
#  '做',
#  '市面',
#  '最',
#  '轻薄',
#  '大屏',
#  '旗舰',
#  '的',
#  '设定',
#  '有关',
#  '按照',
#  '目前',
#  '掌握',
#  '的',
#  '资料',
#  '一加',
#  '手机',
#  '5',
#  '拥有',
#  '55',
#  '寸',
#  '1080P',
#  '三星',
#  'AMOLED',
#  '显示屏',
#  '6G8GBRAM64GB128GBROM',
#  '双',
#  '1600',
#  '万',
#  '摄像头',
#  '备货',
#  '量',
#  '惊喜',
#  '根据',
#  '京东',
#  '泄露',
#  '的',
#  '信息',
#  '一加',
#  '5',
#  '起',
#  '售价',
#  '是',
#  'xx99',
#  '元',
#  '应该',
#  '是',
#  '在',
#  '279928992999',
#  '中',
#  '的',
#  '某个',
#  '\n',
#  '这是',
#  '6',
#  '月',
#  '18',
#  '日',
#  '在',
#  '葡萄牙',
#  '中部',
#  '大',
#  '佩德罗',
#  '冈',
#  '地区',
#  '拍摄',
#  '的',
#  '被',
#  '森林',
#  '大火',
#  '烧毁',
#  '的',
#  '汽车',
#  '新华社',
#  '记者',
#  '张立',
#  '云摄',
#  '\n',
#  '原',
#  '标题',
#  '44',
#  '岁',
#  '女子',
#  '跑',
#  '深圳',
#  '约会',
#  '网友',
#  '被',
#  '拒',
#  '暴雨',
#  '中',
#  '裸身',
#  '奔走',
#  '深圳',
#  '交警',
#  '微博称',
#  '昨日',
#  '清晨',
#  '交警',
#  '发现',
#  '有',
#  '一',
#  '女子',
#  '赤裸',
#  '上身',
#  '行走',
#  '在',
#  '南坪',
#  '快速',
#  '上',
#  '期间',
#  '还',
#  '起',
#  '了',
#  '轻生',
#  '年头',
#  '一辅警',
#  '发现',
#  '后',
#  '赶紧',
#  '为',
#  '其',
#  '披上',
#  '黄衣',
#  '并',
#  '一路',
#  '劝说',
#  '她',
#  '那么',
#  '事发',
#  '时',
#  '到底',
#  '都',
#  '发生',
#  '了',
#  '些',
#  '什么',
#  '呢',
#  '南',
#  '都',
#  '记者',
#  '带',
#  '您',
#  '一起',
#  '还原',
#  '现场',
#  '南',
#  '都',
#  '记者',
#  '在',
#  '龙岗',
#  '大队',
#  '坂田',
#  '中队',
#  '见到',
#  '了',
#  '辅警',
#  '刘青',
#  '发现',
#  '女生',
#  '的',
#  '辅警',
#  '一位',
#  '外表',
#  '高大',
#  '帅气',
#  '说话',
#  '略带',
#  '些',
#  '腼腆',
#  '的',
#  '90',
#  '后',
#  '青年',
#  '刘青',
#  '介绍',
#  '6',
#  '月',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '36',
#  '分',
#  '他',
#  '正在',
#  '环城',
#  '南路',
#  '附近',
#  '值勤',
#  '接到',
#  '中队',
#  '关于',
#  '一位',
#  '女子',
#  '裸身',
#  '进入',
#  '机动车',
#  '可能',
#  '有',
#  '危险',
#  '的',
#  '警情',
#  '随后',
#  '骑着',
#  '小',
#  '铁骑',
#  '开始',
#  '沿路',
#  '寻找',
#  '大概',
#  '花',
#  '了',
#  '十多分钟',
#  '在',
#  '南坪',
#  '大道',
#  '坂田',
#  '出口',
#  '往',
#  '龙岗',
#  '方向',
#  '的',
#  '逆行',
#  '辅道',
#  '上',
#  '发现',
#  '该',
#  '女子',
#  '女子',
#  '身上',
#  '一丝不挂',
#  '地逆',
#  '车流',
#  '而',
#  '行时',
#  '走时',
#  '停时',
#  '坐时',
#  '躺',
#  '险象环生',
#  '刘青停',
#  '好',
#  '小',
#  '铁骑',
#  '和',
#  '另外',
#  '一名',
#  '巡防',
#  '员',
#  '追',
#  '了',
#  '上去',
#  '发现',
#  '女子',
#  '的',
#  '情绪',
#  '很',
#  '低落',
#  '话',
#  '不',
#  '多',
#  '刘青',
#  '尝试',
#  '和',
#  '女子',
#  '交流',
#  '劝说',
#  '女子',
#  '离开',
#  '可',
#  '女子',
#  '并',
#  '不',
#  '愿意',
#  '接受',
#  '继续',
#  '缓慢',
#  '地往',
#  '南坪',
#  '快速路',
#  '的',
#  '主干道',
#  '上',
#  '走',
#  '去',
#  '此时',
#  '路边',
#  '上',
#  '已经',
#  '聚集',
#  '了',
#  '很',
#  '市民',
#  '围观',
#  '为了',
#  '不',
#  '刺激',
#  '女子',
#  '的',
#  '情绪',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '一边',
#  '盯',
#  '着',
#  '女子',
#  '一边',
#  '驱赶',
#  '着',
#  '围观',
#  '的',
#  '群众',
#  '现场',
#  '还原',
#  '从',
#  '警方',
#  '提供',
#  '的',
#  '一份',
#  '视频',
#  '了解',
#  '到',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '25',
#  '分',
#  '女子',
#  '出现',
#  '在',
#  '坂雪岗',
#  '大道',
#  '与',
#  '环城',
#  '南路',
#  '的',
#  '监控',
#  '视频',
#  '中',
#  '此时',
#  '女子',
#  '还',
#  '穿着',
#  '白色',
#  '的',
#  '内裤',
#  '正',
#  '沿着',
#  '坂雪岗',
#  '大道',
#  '往',
#  '南坪',
#  '快速',
#  '的',
#  '方向',
#  '缓慢',
#  '地',
#  '走',
#  '着',
#  '当时',
#  '正值',
#  '上班',
#  '高峰期',
#  '十字路口',
#  '的',
#  '车流',
#  '已经',
#  '排起',
#  '了',
#  '长队',
#  '当',
#  '女子',
#  '出现',
#  '时',
#  '路上',
#  '的',
#  '市民',
#  '纷纷',
#  '驻足',
#  '观望',
#  '不少',
#  '车辆',
#  '也',
#  '放慢',
#  '了',
#  '速度',
#  '但',
#  '女子',
#  '并',
#  '不',
#  '为',
#  '市民',
#  '观望',
#  '停下',
#  '脚步',
#  '依然',
#  '缓慢',
#  '走',
#  '着',
#  '当',
#  '女子',
#  '行进',
#  '到',
#  '十字路口',
#  '中间',
#  '时',
#  '一辆',
#  '大',
#  '货车',
#  '挡住',
#  '了',
#  '镜头',
#  '但是',
#  '当',
#  '女子',
#  '再次出现',
#  '镜头',
#  '时',
#  '可以',
#  '发现',
#  '女子',
#  '已经',
#  '没',
#  '穿',
#  '内裤',
#  '了',
#  '全身',
#  '裸露',
#  '继续',
#  '朝着',
#  '南坪',
#  '快速',
#  '方向',
#  '走',
#  '去',
#  '记者',
#  '发现',
#  '视频',
#  '中',
#  '女子',
#  '周围',
#  '并',
#  '没有',
#  '人',
#  '尾随',
#  '或者',
#  '上前',
#  '劝止',
#  '的',
#  '市民',
#  '一',
#  '大清早',
#  '路上',
#  '看到',
#  '这样',
#  '的',
#  '情况',
#  '恐怕',
#  '大家',
#  '都',
#  '没',
#  '办法',
#  '淡定',
#  '面对',
#  '这一',
#  '情况',
#  '刘青',
#  '表示',
#  '一',
#  '开始',
#  '根本',
#  '不敢',
#  '看',
#  '她',
#  '心里',
#  '挺',
#  '别扭',
#  '感觉',
#  '很',
#  '尴尬',
#  '但',
#  '当',
#  '刘青',
#  '跟随',
#  '女子',
#  '上',
#  '了',
#  '南坪',
#  '快速路',
#  '主干道',
#  '时',
#  '女子',
#  '作出',
#  '了',
#  '让',
#  '人',
#  '意想不到',
#  '的',
#  '举动',
#  '她',
#  '突然',
#  '靠近',
#  '护栏',
#  '要',
#  '从',
#  '上面',
#  '跳下去',
#  '刘青',
#  '赶忙',
#  '冲上去',
#  '拉住',
#  '了',
#  '女子',
#  '的',
#  '手',
#  '将',
#  '其',
#  '控制',
#  '住',
#  '并',
#  '远离',
#  '护栏',
#  '碍于',
#  '女子',
#  '没有',
#  '穿衣服',
#  '刘青递',
#  '上',
#  '衣服',
#  '女子',
#  '没',
#  '接受',
#  '还',
#  '把',
#  '衣服',
#  '扔',
#  '到',
#  '排水沟',
#  '里',
#  '继续',
#  '往前走',
#  '没',
#  '办法',
#  '刘青',
#  '只能',
#  '紧紧',
#  '拉',
#  '着',
#  '她',
#  '的',
#  '一只',
#  '手',
#  '跟',
#  '在',
#  '后面',
#  '刘青',
#  '一路上',
#  '耐心',
#  '地',
#  '开导',
#  '安慰',
#  '她',
#  '但',
#  '只',
#  '听到',
#  '她',
#  '不断',
#  '地',
#  '重复',
#  '着',
#  '一句',
#  '话',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '的',
#  '期间',
#  '她',
#  '还',
#  '不时',
#  '试图',
#  '挣脱',
#  '刘青',
#  '的',
#  '手要',
#  '冲向',
#  '护栏',
#  '往下跳',
#  '就',
#  '这样',
#  '我',
#  '被',
#  '牵',
#  '着',
#  '走',
#  '了',
#  '大概',
#  '十多分钟',
#  '天',
#  '突然',
#  '下起',
#  '了',
#  '大暴雨',
#  '雨大',
#  '的',
#  '连',
#  '眼睛',
#  '都',
#  '睁不开',
#  '刘青',
#  '继续',
#  '说',
#  '着',
#  '瞬间',
#  '他们',
#  '就',
#  '被',
#  '雨',
#  '透',
#  '了',
#  '但',
#  '女子',
#  '依然',
#  '不',
#  '愿意',
#  '接受',
#  '刘青',
#  '的',
#  '帮助',
#  '就',
#  '继续',
#  '冒',
#  '着',
#  '大雨',
#  '往前走',
#  '大概',
#  '走',
#  '了',
#  '有',
#  '四十分钟',
#  '吧',
#  '女子',
#  '突然',
#  '停下',
#  '来说',
#  '我',
#  '想',
#  '回家',
#  '了',
#  '然后',
#  '女子',
#  '也',
#  '接受',
#  '了',
#  '刘青',
#  '递过来',
#  '的',
#  '小',
#  '黄衣',
#  '就',
#  '出现',
#  '了',
#  '深圳',
#  '微博上',
#  '的',
#  '照片',
#  '女子',
#  '披着',
#  '小',
#  '黄衣',
#  '刘青',
#  '小心翼翼',
#  '地',
#  '在',
#  '旁边',
#  '走',
#  '着',
#  '的',
#  '场景',
#  '从',
#  '南平',
#  '快速',
#  '下来',
#  '后',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '将',
#  '女子',
#  '带到',
#  '了',
#  '附近',
#  '的',
#  '坂田',
#  '派出所',
#  '那',
#  '姑娘',
#  '到底',
#  '是',
#  '遭遇',
#  '了',
#  '什么样',
#  '的',
#  '事情',
#  '才',
#  '会',
#  '说',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '据',
#  '警方',
#  '透露',
#  '该',
#  '女子',
#  '姓',
#  '陈系',
#  '湖北',
#  '人',
#  '今年',
#  '44',
#  '岁',
#  '据',
#  '家属',
#  '反映',
#  '其有',
#  '精神病',
#  '史',
#  '三天',
#  '前',
#  '陈某',
#  '从',
#  '老家',
#  '来',
#  '深圳',
#  '约会',
#  '网友',
#  '但',
#  '约会',
#  '受挫',
#  '导致',
#  '情绪',
#  '异常',
#  '女子',
#  '遂',
#  '产生',
#  '轻生',
#  '念头',
#  ...]

# %%
TOKEN_2_GRAM = [''.join(TOKEN[i:i+2]) for i in range(len(TOKEN[:-2]))]

# %%
TOKEN_2_GRAM[:10]
# Out:
# ['此外自', '自本周', '本周6', '6月', '月12', '12日起', '日起除', '除小米', '小米手机', '手机6']

# %%
len(TOKEN_2_GRAM)
# Out:
# 21312108

# %%
words_count_2 = Counter(TOKEN_2_GRAM)

# %%
words_count_2
# Out:
# Counter({'此外自': 9,
#          '自本周': 4,
#          '本周6': 6,
#          '6月': 25438,
#          '月12': 4707,
#          '12日起': 10,
#          '日起除': 2,
#          '除小米': 2,
#          '小米手机': 13,
#          '手机6': 2,
#          '6等': 2,
#          '等15': 62,
#          '15款': 10,
#          '款机型': 3,
#          '机型外': 2,
#          '外其余': 65,
#          '其余机型': 2,
#          '机型已': 2,
#          '已暂停': 17,
#          '暂停更新': 2,
#          '更新发布': 2,
#          '发布含': 2,
#          '含开发': 2,
#          '开发版': 2,
#          '版体验版': 2,
#          '体验版内测': 2,
#          '内测稳定版': 2,
#          '稳定版暂不受': 2,
#          '暂不受影响': 2,
#          '影响以': 18,
#          '以确保': 158,
#          '确保工程师': 2,
#          '工程师可以': 2,
#          '可以集中': 6,
#          '集中全部': 2,
#          '全部精力': 12,
#          '精力进行': 2,
#          '进行系统优化': 2,
#          '系统优化工作': 2,
#          '工作有人': 4,
#          '有人猜测': 7,
#          '猜测这': 12,
#          '这也': 2151,
#          '也是': 9176,
#          '是将': 215,
#          '将精力': 17,
#          '精力主要': 2,
#          '主要用到': 2,
#          '用到MIUI9': 2,
#          'MIUI9的': 4,
#          '的研发': 472,
#          '研发之中': 3,
#          '之中MIUI8': 2,
#          'MIUI8去年': 2,
#          '去年5': 104,
#          '5月': 40088,
#          '月发布': 139,
#          '发布距今已有': 2,
#          '距今已有一年': 2,
#          '一年有余': 5,
#          '有余也': 2,
#          '是时候': 56,
#          '时候更新换代': 2,
#          '更新换代了': 2,
#          '了当然': 23,
#          '当然关于': 2,
#          '关于MIUI9': 2,
#          '的确切': 35,
#          '确切信息': 7,
#          '信息我们': 13,
#          '我们还是': 59,
#          '还是等待': 4,
#          '等待官方消息': 2,
#          '官方消息\n': 2,
#          '\n骁龙': 2,
#          '骁龙835': 32,
#          '835作为': 4,
#          '作为唯一': 28,
#          '唯一通过': 8,
#          '通过Windows10': 2,
#          'Windows10桌面': 4,
#          '桌面平台': 6,
#          '平台认证': 2,
#          '认证的': 104,
#          '的ARM': 2,
#          'ARM处理器': 2,
#          '处理器高通': 2,
#          '高通强调': 2,
#          '强调不会': 12,
#          '不会因为': 74,
#          '因为只': 4,
#          '只考虑': 27,
#          '考虑性能': 2,
#          '性能而': 2,
#          '而去': 58,
#          '去屏蔽掉': 2,
#          '屏蔽掉小': 2,
#          '小核心': 6,
#          '核心相反': 2,
#          '相反他们': 9,
#          '他们正': 38,
#          '正联手': 3,
#          '联手微软': 2,
#          '微软找到': 2,
#          '找到一种': 16,
#          '一种适合': 2,
#          '适合桌面': 2,
#          '平台的': 570,
#          '的兼顾': 2,
#          '兼顾性能': 2,
#          '性能和': 37,
#          '和功耗': 4,
#          '功耗的': 6,
#          '的完美': 78,
#          '完美方案': 2,
#          '方案报道': 2,
#          '报道称': 1821,
#          '称微软': 4,
#          '微软已经': 4,
#          '已经拿到': 10,
#          '拿到了': 259,
#          '了一些': 745,
#          '一些新': 102,
#          '新的': 5360,
#          '的源码': 2,
#          '源码以便': 2,
#          '以便Windows10': 2,
#          'Windows10更好': 2,
#          '更好地': 1274,
#          '地理解': 61,
#          '理解biglittle': 2,
#          'biglittle架构': 2,
#          '架构资料': 2,
#          '资料显示': 323,
#          '显示骁龙': 2,
#          '作为一款': 21,
#          '一款集成': 2,
#          '集成了': 13,
#          '了CPUGPU': 2,
#          'CPUGPU基带': 2,
#          '基带蓝牙': 6,
#          '蓝牙WiFi': 2,
#          'WiFi的': 8,
#          '的SoC': 4,
#          'SoC比': 2,
#          '比传统': 42,
#          '传统的': 1010,
#          '的Wintel': 4,
#          'Wintel方案': 2,
#          '方案可以': 6,
#          '可以节省': 13,
#          '节省至少': 2,
#          '至少30': 16,
#          '30的': 143,
#          '的PCB': 2,
#          'PCB空间': 2,
#          '空间按计划': 2,
#          '按计划今年': 2,
#          '今年Q4': 2,
#          'Q4华硕': 2,
#          '华硕惠普': 4,
#          '惠普联想': 2,
#          '联想将': 4,
#          '将首发': 5,
#          '首发骁龙': 4,
#          '骁龙835Win10': 2,
#          '835Win10电脑': 2,
#          '电脑预计': 2,
#          '预计均': 4,
#          '均是': 166,
#          '是二合一': 2,
#          '二合一形态': 2,
#          '形态的': 47,
#          '的产品': 1329,
#          '产品当然': 4,
#          '当然高通': 2,
#          '高通骁龙': 26,
#          '骁龙只是': 2,
#          '只是个': 52,
#          '个开始': 10,
#          '开始未来': 9,
#          '未来也许': 7,
#          '也许还': 9,
#          '还能': 1083,
#          '能见到': 29,
#          '见到三星': 2,
#          '三星Exynos': 2,
#          'Exynos联发科': 2,
#          '联发科华为': 4,
#          '华为麒麟': 2,
#          '麒麟小米': 2,
#          '小米澎湃': 2,
#          '澎湃等': 4,
#          '等进入': 8,
#          '进入Windows10': 2,
#          '平台\n': 14,
#          '\n此前': 18,
#          '此前的': 270,
#          '的一加': 2,
#          '一加3T': 2,
#          '3T搭载': 2,
#          '搭载的': 57,
#          '的是': 8329,
#          '是3400mAh': 2,
#          '3400mAh电池': 2,
#          '电池DashCharge': 2,
#          'DashCharge快充': 2,
#          '快充规格': 2,
#          '规格为': 7,
#          '为5V4A': 2,
#          '5V4A至于': 2,
#          '至于电池': 2,
#          '电池缩水': 2,
#          '缩水可能': 2,
#          '可能与': 142,
#          '与刘作': 2,
#          '刘作虎': 6,
#          '虎所说': 2,
#          '所说一加': 2,
#          '一加手机': 8,
#          '手机5': 10,
#          '5要': 2,
#          '要做': 332,
#          '做市面': 2,
#          '市面最': 2,
#          '最轻薄': 4,
#          '轻薄大屏': 2,
#          '大屏旗舰': 2,
#          '旗舰的': 4,
#          '的设定': 29,
#          '设定有关': 2,
#          '有关按照': 4,
#          '按照目前': 39,
#          '目前掌握': 26,
#          '掌握的': 189,
#          '的资料': 239,
#          '资料一加': 2,
#          '5拥有': 4,
#          '拥有55': 2,
#          '55寸': 8,
#          '寸1080P': 2,
#          '1080P三星': 2,
#          '三星AMOLED': 2,
#          'AMOLED显示屏': 3,
#          '显示屏6G8GBRAM64GB128GBROM': 2,
#          '6G8GBRAM64GB128GBROM双': 2,
#          '双1600': 2,
#          '1600万': 14,
#          '万摄像头': 3,
#          '摄像头备货': 2,
#          '备货量': 2,
#          '量惊喜': 2,
#          '惊喜根据': 2,
#          '根据京东': 15,
#          '京东泄露': 2,
#          '泄露的': 60,
#          '的信息': 1044,
#          '信息一加': 2,
#          '一加5': 40,
#          '5起': 24,
#          '起售价': 8,
#          '售价是': 8,
#          '是xx99': 2,
#          'xx99元': 2,
#          '元应该': 2,
#          '应该是': 514,
#          '是在': 3726,
#          '在279928992999': 2,
#          '279928992999中': 2,
#          '中的': 6750,
#          '的某个': 36,
#          '某个\n': 2,
#          '\n这是': 28,
#          '这是6': 175,
#          '月18': 5326,
#          '18日': 5472,
#          '日在': 27814,
#          '在葡萄牙': 265,
#          '葡萄牙中部': 11,
#          '中部大': 13,
#          '大佩德罗': 4,
#          '佩德罗冈': 4,
#          '冈地区': 4,
#          '地区拍摄': 25,
#          '拍摄的': 4398,
#          '的被': 93,
#          '被森林': 4,
#          '森林大火': 19,
#          '大火烧毁': 5,
#          '烧毁的': 13,
#          '的汽车': 408,
#          '汽车新华社': 8,
#          '新华社记者': 31006,
#          '记者张立': 119,
#          '张立云摄': 115,
#          '云摄\n': 85,
#          '\n原': 1687,
#          '原标题': 1935,
#          '标题44': 2,
#          '44岁': 53,
#          '岁女子': 21,
#          '女子跑': 2,
#          '跑深圳': 2,
#          '深圳约会': 6,
#          '约会网友': 6,
#          '网友被': 5,
#          '被拒': 36,
#          '拒暴雨': 2,
#          '暴雨中': 8,
#          '中裸身': 2,
#          '裸身奔走': 2,
#          '奔走深圳': 2,
#          '深圳交警': 9,
#          '交警微博称': 4,
#          '微博称昨日': 2,
#          '昨日清晨': 2,
#          '清晨交警': 4,
#          '交警发现': 4,
#          '发现有': 196,
#          '有一': 84,
#          '一女子': 35,
#          '女子赤裸': 4,
#          '赤裸上身': 11,
#          '上身行走': 4,
#          '行走在': 119,
#          '在南坪': 11,
#          '南坪快速': 12,
#          '快速上': 8,
#          '上期间': 4,
#          '期间还': 103,
#          '还起': 4,
#          '起了': 345,
#          '了轻生': 8,
#          '轻生年头': 4,
#          '年头一辅警': 4,
#          '一辅警发现': 4,
#          '发现后': 43,
#          '后赶紧': 8,
#          '赶紧为': 6,
#          '为其': 421,
#          '其披上': 4,
#          '披上黄衣': 4,
#          '黄衣并': 4,
#          '并一路': 12,
#          '一路劝说': 4,
#          '劝说她': 4,
#          '她那么': 4,
#          '那么事发': 2,
#          '事发时': 117,
#          '时到底': 2,
#          '到底都': 4,
#          '都发生': 42,
#          '发生了': 711,
#          '了些': 64,
#          '些什么': 30,
#          '什么呢': 70,
#          '呢南': 4,
#          '南都': 46,
#          '都记者': 30,
#          '记者带': 45,
#          '带您': 20,
#          '您一起': 19,
#          '一起还原': 2,
#          '还原现场': 4,
#          '现场南': 2,
#          '记者在': 1313,
#          '在龙岗': 2,
#          '龙岗大队': 4,
#          '大队坂田': 4,
#          '坂田中队': 4,
#          '中队见到': 4,
#          '见到了': 146,
#          '了辅警': 4,
#          '辅警刘青': 4,
#          '刘青发现': 4,
#          '发现女生': 4,
#          '女生的': 40,
#          '的辅警': 8,
#          '辅警一位': 4,
#          '一位外表': 6,
#          '外表高大': 4,
#          '高大帅气': 4,
#          '帅气说话': 4,
#          '说话略带': 4,
#          '略带些': 4,
#          '些腼腆': 4,
#          '腼腆的': 21,
#          '的90': 95,
#          '90后': 260,
#          '后青年': 25,
#          '青年刘青': 4,
#          '刘青介绍': 4,
#          '介绍6': 15,
#          '月16': 4798,
#          '16日': 4777,
#          '日早上': 126,
#          '早上7': 48,
#          '7时': 237,
#          '时36': 9,
#          '36分': 15,
#          '分他': 23,
#          '他正在': 71,
#          '正在环城': 4,
#          '环城南路': 8,
#          '南路附近': 6,
#          '附近值勤': 4,
#          '值勤接到': 4,
#          '接到中队': 4,
#          '中队关于': 4,
#          '关于一位': 4,
#          '一位女子': 9,
#          '女子裸身': 4,
#          '裸身进入': 4,
#          '进入机动车': 4,
#          '机动车可能': 4,
#          '可能有': 195,
#          '有危险': 34,
#          '危险的': 209,
#          '的警情': 7,
#          '警情随后': 4,
#          '随后骑着': 4,
#          '骑着小': 6,
#          '小铁骑': 8,
#          '铁骑开始': 4,
#          '开始沿路': 4,
#          '沿路寻找': 4,
#          '寻找大概': 4,
#          '大概花': 5,
#          '花了': 263,
#          '了十多分钟': 6,
#          '十多分钟在': 4,
#          '南坪大道': 4,
#          '大道坂田': 4,
#          '坂田出口': 4,
#          '出口往': 4,
#          '往龙岗': 4,
#          '龙岗方向': 4,
#          '方向的': 171,
#          '的逆行': 5,
#          '逆行辅道': 4,
#          '辅道上': 4,
#          '上发现': 62,
#          '发现该': 102,
#          '该女子': 83,
#          '女子女子': 9,
#          '女子身上': 8,
#          '身上一丝不挂': 4,
#          '一丝不挂地逆': 4,
#          '地逆车流': 4,
#          '车流而': 4,
#          '而行时': 5,
#          '行时走时': 4,
#          '走时停时': 4,
#          '停时坐时': 4,
#          '坐时躺': 4,
#          '躺险象环生': 4,
#          '险象环生刘青停': 4,
#          '刘青停好': 4,
#          '好小': 6,
#          '铁骑和': 4,
#          '和另外': 49,
#          '另外一名': 44,
#          '一名巡防': 4,
#          '巡防员': 12,
#          '员追': 4,
#          '追了': 15,
#          '了上去': 23,
#          '上去发现': 4,
#          '发现女子': 8,
#          '女子的': 66,
#          '的情绪': 220,
#          '情绪很': 9,
#          '很低落': 6,
#          '低落话': 4,
#          '话不': 23,
#          '不多': 226,
#          '多刘青': 4,
#          '刘青尝试': 4,
#          '尝试和': 15,
#          '和女子': 33,
#          '女子交流': 4,
#          '交流劝说': 4,
#          '劝说女子': 4,
#          '女子离开': 4,
#          '离开可': 4,
#          '可女子': 4,
#          '女子并': 22,
#          '并不': 2590,
#          '不愿意': 378,
#          '愿意接受': 46,
#          '接受继续': 4,
#          '继续缓慢': 5,
#          '缓慢地往': 4,
#          '地往南坪': 4,
#          '南坪快速路': 8,
#          '快速路的': 8,
#          '的主干道': 12,
#          '主干道上': 7,
#          '上走': 69,
#          '走去': 28,
#          '去此时': 4,
#          '此时路边': 4,
#          '路边上': 6,
#          '上已经': 85,
#          '已经聚集': 9,
#          '聚集了': 135,
#          '了很': 293,
#          '很市民': 4,
#          '市民围观': 6,
#          '围观为了': 4,
#          '为了不': 76,
#          '不刺激': 5,
#          '刺激女子': 4,
#          '情绪刘青': 4,
#          '刘青和': 8,
#          '和巡防': 9,
#          '员一边': 4,
#          '一边盯': 5,
#          '盯着': 121,
#          '着女子': 5,
#          '女子一边': 4,
#          '一边驱赶': 4,
#          '驱赶着': 4,
#          '着围观': 4,
#          '围观的': 33,
#          '的群众': 208,
#          '群众现场': 5,
#          '现场还原': 6,
#          '还原从': 4,
#          '从警方': 19,
#          '警方提供': 27,
#          '提供的': 1065,
#          '的一份': 418,
#          '一份视频': 4,
#          '视频了解': 7,
#          '了解到': 2296,
#          '到16': 31,
#          '时25': 25,
#          '25分': 35,
#          '分女子': 4,
#          '女子出现': 8,
#          '出现在': 984,
#          '在坂雪岗': 4,
#          '坂雪岗大道': 8,
#          '大道与': 10,
#          '与环城': 4,
#          '南路的': 11,
#          '的监控': 98,
#          '监控视频': 93,
#          '视频中': 278,
#          '中此时': 6,
#          '此时女子': 4,
#          '女子还': 9,
#          '还穿着': 14,
#          '穿着白色': 6,
#          '白色的': 92,
#          '的内裤': 12,
#          '内裤正': 4,
#          '正沿着': 18,
#          '沿着坂雪岗': 4,
#          '大道往': 4,
#          '往南坪': 4,
#          '快速的': 85,
#          '的方向': 601,
#          '方向缓慢': 5,
#          '缓慢地': 15,
#          '地走': 70,
#          '走着': 28,
#          '着当时': 4,
#          '当时正值': 26,
#          '正值上班': 7,
#          '上班高峰期': 9,
#          '高峰期十字路口': 4,
#          '十字路口的': 11,
#          '的车流': 18,
#          '车流已经': 6,
#          '已经排起': 4,
#          '排起了': 35,
#          '了长队': 31,
#          '长队当': 4,
#          '当女子': 12,
#          '出现时': 52,
#          '时路上': 6,
#          '路上的': 166,
#          '的市民': 319,
#          '市民纷纷': 21,
#          '纷纷驻足': 11,
#          '驻足观望': 4,
#          '观望不少': 4,
#          '不少车辆': 8,
#          '车辆也': 19,
#          '也放慢': 4,
#          '放慢了': 10,
#          '了速度': 10,
#          '速度但': 4,
#          '但女子': 8,
#          '不为': 96,
#          '为市民': 103,
#          '市民观望': 4,
#          '观望停下': 4,
#          '停下脚步': 33,
#          '脚步依然': 4,
#          '依然缓慢': 8,
#          '缓慢走': 4,
#          '着当': 8,
#          '女子行进': 4,
#          '行进到': 6,
#          '到十字路口': 6,
#          '十字路口中间': 4,
#          '中间时': 5,
#          '时一辆': 20,
#          '一辆大': 15,
#          '大货车': 75,
#          '货车挡住': 4,
#          '挡住了': 27,
#          '了镜头': 7,
#          '镜头但是': 4,
#          '但是当': 31,
#          '女子再次出现': 4,
#          '再次出现镜头': 4,
#          '镜头时': 4,
#          '时可以': 73,
#          '可以发现': 100,
#          '女子已经': 6,
#          '已经没': 18,
#          '没穿': 16,
#          '穿内裤': 4,
#          '内裤了': 4,
#          '了全身': 4,
#          '全身裸露': 4,
#          '裸露继续': 4,
#          '继续朝着': 8,
#          '朝着南坪': 4,
#          '快速方向': 4,
#          '方向走': 22,
#          '去记者': 4,
#          '记者发现': 194,
#          '发现视频': 4,
#          '中女子': 7,
#          '女子周围': 4,
#          '周围并': 5,
#          '并没有': 1645,
#          '没有人': 186,
#          '人尾随': 4,
#          '尾随或者': 4,
#          '或者上前': 4,
#          '上前劝止': 4,
#          '劝止的': 4,
#          '市民一': 6,
#          '一大清早': 4,
#          '大清早路上': 4,
#          '路上看到': 14,
#          '看到这样': 29,
#          '这样的': 3734,
#          '的情况': 3998,
#          '情况恐怕': 4,
#          '恐怕大家': 5,
#          '大家都': 597,
#          '都没': 215,
#          '没办法': 142,
#          '办法淡定': 4,
#          '淡定面对': 4,
#          '面对这一': 31,
#          '这一情况': 50,
#          '情况刘青': 4,
#          '刘青表示': 4,
#          '表示一': 8,
#          '一开始': 471,
#          '开始根本': 4,
#          '根本不敢': 14,
#          '不敢看': 7,
#          '看她': 67,
#          '她心里': 16,
#          '心里挺': 18,
#          '挺别扭': 4,
#          '别扭感觉': 4,
#          '感觉很': 104,
#          '很尴尬': 19,
#          '尴尬但': 7,
#          '但当': 97,
#          '当刘青': 4,
#          '刘青跟随': 4,
#          '跟随女子': 4,
#          '女子上': 4,
#          '上了': 920,
#          '了南坪': 4,
#          '快速路主干道': 4,
#          '主干道时': 4,
#          '时女子': 4,
#          '女子作出': 4,
#          '作出了': 459,
#          '了让': 98,
#          '让人': 1422,
#          '人意想不到': 8,
#          '意想不到的': 64,
#          '的举动': 173,
#          '举动她': 5,
#          '她突然': 20,
#          '突然靠近': 4,
#          '靠近护栏': 4,
#          '护栏要': 4,
#          '要从': 267,
#          '从上面': 6,
#          '上面跳下去': 4,
#          '跳下去刘青': 4,
#          '刘青赶忙': 4,
#          '赶忙冲上去': 4,
#          '冲上去拉住': 4,
#          '拉住了': 4,
#          '了女子': 36,
#          '的手': 223,
#          '手将': 7,
#          '将其': 981,
#          '其控制': 24,
#          '控制住': 53,
#          '住并': 11,
#          '并远离': 9,
#          '远离护栏': 4,
#          '护栏碍于': 4,
#          '碍于女子': 4,
#          '女子没有': 4,
#          '没有穿衣服': 4,
#          '穿衣服刘青递': 4,
#          '刘青递上': 4,
#          '上衣服': 13,
#          '衣服女子': 4,
#          '女子没': 7,
#          '没接受': 4,
#          '接受还': 4,
#          '还把': 113,
#          '把衣服': 11,
#          '衣服扔': 4,
#          '扔到': 51,
#          '到排水沟': 4,
#          '排水沟里': 4,
#          '里继续': 6,
#          '继续往前走': 7,
#          '往前走没': 4,
#          '办法刘青': 4,
#          '刘青只能': 4,
#          '只能紧紧': 4,
#          '紧紧拉': 4,
#          '拉着': 36,
#          '着她': 80,
#          '她的': 1824,
#          '的一只': 220,
#          '一只手': 20,
#          '手跟': 4,
#          '跟在': 46,
#          '在后面': 71,
#          '后面刘青': 4,
#          '刘青一路上': 4,
#          '一路上耐心': 4,
#          '耐心地': 36,
#          '地开导': 4,
#          '开导安慰': 4,
#          '安慰她': 18,
#          '她但': 10,
#          '但只': 23,
#          '只听到': 10,
#          '听到她': 8,
#          '她不断': 6,
#          '不断地': 156,
#          '地重复': 11,
#          '重复着': 16,
#          '着一句': 7,
#          '一句话': 349,
#          '话要是': 4,
#          '要是你': 14,
#          '你也': 85,
#          '也遭遇': 35,
#          '遭遇我': 8,
#          '我的': 2843,
#          '的事': 982,
#          '事你': 19,
#          '也会': 1801,
#          '会这样': 36,
#          '的期间': 12,
#          '期间她': 36,
#          '她还': 270,
#          '还不时': 22,
#          '不时试图': 4,
#          '试图挣脱': 7,
#          '挣脱刘青': 4,
#          '刘青的': 8,
#          '的手要': 8,
#          '手要冲向': 4,
#          '冲向护栏': 4,
#          '护栏往下跳': 4,
#          '往下跳就': 4,
#          '就这样': 240,
#          '这样我': 24,
#          '我被': 43,
#          '被牵': 6,
#          '牵着': 32,
#          '着走': 24,
#          '走了': 353,
#          '了大概': 21,
#          '大概十多分钟': 4,
#          '十多分钟天': 4,
#          '天突然': 4,
#          '突然下起': 4,
#          '下起了': 5,
#          '了大暴雨': 4,
#          '大暴雨雨大': 4,
#          '雨大的': 4,
#          '的连': 23,
#          '连眼睛': 4,
#          '眼睛都': 13,
#          '都睁不开': 4,
#          '睁不开刘青': 4,
#          '刘青继续': 4,
#          '继续说': 12,
#          '说着': 93,
#          '着瞬间': 4,
#          '瞬间他们': 6,
#          '他们就': 160,
#          '就被': 368,
#          '被雨': 4,
#          '雨透': 4,
#          '透了': 11,
#          '了但': 393,
#          '女子依然': 4,
#          '依然不': 16,
#          '接受刘青': 4,
#          '的帮助': 470,
#          '帮助就': 7,
#          '就继续': 24,
#          '继续冒': 4,
#          '冒着': 141,
#          '着大雨': 15,
#          '大雨往前走': 4,
#          '往前走大概': 4,
#          '大概走': 6,
#          '了有': 209,
#          '有四十分钟': 4,
#          '四十分钟吧': 4,
#          '吧女子': 4,
#          '女子突然': 7,
#          '突然停下': 4,
#          '停下来说': 4,
#          '来说我': 22,
#          '我想': 606,
#          '想回家': 12,
#          '回家了': 32,
#          '了然后': 54,
#          '然后女子': 4,
#          '女子也': 11,
#          '也接受': 37,
#          '接受了': 406,
#          '了刘青': 4,
#          '刘青递过来': 4,
#          '递过来的': 14,
#          '的小': 1066,
#          '小黄衣': 8,
#          '黄衣就': 4,
#          '就出现': 89,
#          '出现了': 1360,
#          '了深圳': 50,
#          '深圳微博上': 4,
#          '微博上的': 10,
#          '的照片': 585,
#          '照片女子': 4,
#          '女子披着': 4,
#          '披着小': 4,
#          '黄衣刘青': 4,
#          '刘青小心翼翼': 4,
#          '小心翼翼地': 53,
#          '地在': 218,
#          '在旁边': 71,
#          '旁边走': 5,
#          '着的': 168,
#          '的场景': 310,
#          '场景从': 4,
#          '从南平': 4,
#          '南平快速': 4,
#          '快速下来': 4,
#          '下来后': 9,
#          '后刘青': 4,
#          '员将': 23,
#          '将女子': 21,
#          '女子带到': 4,
#          '带到了': 61,
#          '了附近': 37,
#          '附近的': 1411,
#          '的坂田': 4,
#          '坂田派出所': 4,
#          '派出所那': 4,
#          '那姑娘': 4,
#          '姑娘到底': 4,
#          '到底是': 179,
#          '是遭遇': 6,
#          '遭遇了': 141,
#          '了什么样': 12,
#          '什么样的': 444,
#          '的事情': 1026,
#          '事情才': 4,
#          '才会': 506,
#          '会说': 100,
#          '说要是': 6,
#          '这样据': 2,
#          '据警方': 67,
#          '警方透露': 35,
#          '透露该': 28,
#          '女子姓': 8,
#          '姓陈系': 4,
#          '陈系湖北': 4,
#          '湖北人': 18,
#          '人今年': 47,
#          '今年44': 31,
#          '岁据': 9,
#          '据家属': 4,
#          '家属反映': 4,
#          '反映其有': 4,
#          '其有精神病': 4,
#          '精神病史': 8,
#          '史三天': 4,
#          '三天前': 21,
#          '前陈某': 4,
#          '陈某从': 6,
#          '从老家': 32,
#          '老家来': 6,
#          '来深圳': 18,
#          '网友但': 4,
#          '但约会': 4,
#          '约会受挫': 4,
#          '受挫导致': 4,
#          '导致情绪': 12,
#          '情绪异常': 6,
#          '异常女子': 4,
#          '女子遂': 4,
#          '遂产生': 4,
#          '产生轻生': 10,
#          '轻生念头': 12,
#          '念头目前': 4,
#          '目前陈某': 11,
#          '陈某已经': 6,
#          '已经被': 311,
#          '被送往': 223,
#          '送往深圳': 4,
#          '深圳某': 17,
#          '某精神病': 4,
#          '精神病医院': 10,
#          '医院进行': 103,
#          '进行治疗': 47,
#          '治疗大大': 2,
#          '大大君': 2,
#          '君只': 3,
#          '只希望': 29,
#          '希望姑娘': 2,
#          '姑娘能': 2,
#          '能早点': 8,
#          '早点康复': 4,
#          '康复其实': 2,
#          '其实真爱': 2,
#          '真爱的': 4,
#          '的到来': 484,
#          '到来并': 10,
#          '不存在': 492,
#          '存在年龄': 2,
#          '年龄的': 92,
#          '的限制': 310,
#          '限制你们': 2,
#          '你们说': 15,
#          '说呢': 9,
#          '呢因': 2,
#          '因善良': 2,
#          '善良的': 25,
#          '的原因': 1284,
#          '原因一众': 2,
#          '一众网友': 4,
#          '网友纷纷': 66,
#          '纷纷为': 32,
#          '为交警': 10,
#          '交警暖': 4,
#          '暖男点': 4,
#          '男点ZAN': 4,
#          'ZAN弓常': 4,
#          '弓常yan': 4,
#          'yan桦': 4,
#          '桦就': 4,
#          '就想': 131,
#          '想问': 25,
#          '问这个': 14,
#          '这个小': 45,
#          '小哥哥': 10,
#          '哥哥有': 13,
#          '有女票': 4,
#          '女票吗': 4,
#          '吗原谅': 4,
#          '原谅我': 10,
#          '我这': 70,
#          '这一辈子': 21,
#          '一辈子浪荡': 4,
#          '浪荡不羁': 4,
#          '不羁爱': 5,
#          '爱萨摩耶': 4,
#          '萨摩耶有': 4,
#          '有什么': 486,
#          '什么过不去': 4,
#          ...})

# %%
def prob_1(word): return words_count[word] / len(TOKEN)

# %%
def prob_2(word1, word2):
    if word1 + word2 in words_count_2:
        return words_count_2[word1+word2] / len(TOKEN_2_GRAM)
    else:
        return 1 / len(TOKEN_2_GRAM)

# %%
prob_2('我们', '在')
# Out:
# 3.336131742575629e-05

# %%
prob_2('在', '吃饭')
# Out:
# 2.8153010485870285e-07

# %%
prob_2('去', '吃饭')
# Out:
# 6.5690357800364e-07

# %%
def get_probablity(sentence):
    words = cut(sentence)
    
    sentence_pro = 1
    
    for i, word in enumerate(words[:-1]):
        next_ = words[i+1]
        
        sentence_pro *= prob_2(word, next_)
    
    return sentence_pro

# %%
get_probablity('小明今天抽奖抽到一台苹果手机')
# Out:
# 6.509856048792876e-43

# %%
get_probablity('小明今天抽奖抽到一架波音飞机')
# Out:
# 3.7351633066844376e-42

# %%
get_probablity('洋葱奶昔来一杯')
# Out:
# 1.0330486514175185e-22

# %%
get_probablity('养乐多绿来一杯')
# Out:
# 2.2016444428264508e-15

# %%
for sen in [generate(gram=example_grammar, target='sentence') for i in range(10)]:
    print('sentence: {} with Prb: {}'.format(sen, get_probablity(sen)))
# Out:
# sentence: 这个小猫看着这个桌子 with Prb: 6.78613355368003e-29
# sentence: 一个好看的小猫听着一个蓝色的好看的篮球 with Prb: 1.8096653128195902e-68
# sentence: 一个好看的篮球看见一个蓝色的小小的好看的小小的蓝色的桌子 with Prb: 7.638082023076974e-92
# sentence: 一个好看的好看的蓝色的桌子看见一个蓝色的篮球 with Prb: 1.1968954871653075e-75
# sentence: 这个蓝色的小猫看见这个蓝色的小小的好看的小小的好看的好看的好看的蓝色的篮球 with Prb: 2.354859246951435e-128
# sentence: 一个蓝色的好看的小猫坐在一个蓝色的蓝色的篮球 with Prb: 2.3376101657493863e-75
# sentence: 一个桌子坐在一个蓝色的女人 with Prb: 5.793558445522422e-40
# sentence: 这个蓝色的好看的篮球看见这个篮球 with Prb: 3.9349454855554937e-53
# sentence: 一个好看的篮球看见一个蓝色的蓝色的小小的小猫 with Prb: 3.4705259710448486e-71
# sentence: 一个桌子听着这个小猫 with Prb: 1.3282530003766395e-33

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "今晚我去吃火锅 今晚火锅去吃我",
    "洋葱奶昔来一杯 养乐多绿来一杯"
]

for s in need_compared:
    s1, s2 = s.split()
    p1, p2 = get_probablity(s1), get_probablity(s2)
    
    better = s1 if p1 > p2 else s2
    
    print('{} is more possible'.format(better))
    print('-'*4 + ' {} with probility {}'.format(s1, p1))
    print('-'*4 + ' {} with probility {}'.format(s2, p2))
# Out:
# 今天晚上请你吃大餐，我们一起吃日料 is more possible
# ---- 今天晚上请你吃大餐，我们一起吃日料 with probility 1.1153398866591634e-66
# ---- 明天晚上请你吃大餐，我们一起吃苹果 with probility 9.560056171364259e-67
# 真是一只好看的小猫 is more possible
# ---- 真事一只好看的小猫 with probility 2.6269387250599635e-34
# ---- 真是一只好看的小猫 with probility 5.598560181786025e-27
# 今晚我去吃火锅 is more possible
# ---- 今晚我去吃火锅 with probility 2.7892313588273e-20
# ---- 今晚火锅去吃我 with probility 8.531139324626324e-28
# 养乐多绿来一杯 is more possible
# ---- 洋葱奶昔来一杯 with probility 1.0330486514175185e-22
# ---- 养乐多绿来一杯 with probility 2.2016444428264508e-15

# %% [markdown]
# ## Data Driven
